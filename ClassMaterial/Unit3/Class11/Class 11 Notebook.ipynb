# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor, plot_tree
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/housing.csv')
X = df.drop('PRICE', axis=1)
y = df['PRICE']

# %%
tree = DecisionTreeRegressor(max_depth=3)

# %%
tree.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
plt.figure(figsize=(18, 10))
plot_tree(tree, fontsize=10, filled=True, feature_names=X.columns);

# %%
import numpy as np
root_error = np.mean((df['PRICE'] - df['PRICE'].mean())**2)

# %%
left_side = df[df['RM'] <= 6.941]
right_side = df[df['RM'] > 6.941]

# %%
left_error = np.mean((left_side['PRICE'] - left_side['PRICE'].mean())**2)

# %%
right_error = np.mean((right_side['PRICE'] - right_side['PRICE'].mean())**2)

# %%
left_weight = left_side.shape[0] / df.shape[0]

# %%
right_weight = right_side.shape[0] / df.shape[0]

# %%
root_error - left_weight * left_error - right_weight * right_error
# Out:
# 38.220464479057114

# %%
root_error
# Out:
# 84.4195561561656

# %%
84.42 - 38.22
# Out:
# 46.2

# %%
gradient =  y - y.mean()

# %%
gradient
# Out:
# 0       1.467194
# 1      -0.932806
# 2      12.167194
# 3      10.867194
# 4      13.667194
#          ...
# 501    -0.132806
# 502    -1.932806
# 503     1.367194
# 504    -0.532806
# 505   -10.632806
# Name: PRICE, Length: 506, dtype: float64

# %%
tree = DecisionTreeRegressor(max_depth=3)

# %%
guess = y.mean()

# %%
tree.fit(X, gradient)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
tree.predict(X)
# Out:
# array([  0.37239368,   0.37239368,  10.81603089,  10.81603089,
#         10.81603089,   0.37239368,   0.37239368,  -5.39518256,
#         -5.39518256,  -5.39518256,  -5.39518256,   0.37239368,
#         -5.39518256,   0.37239368,   0.37239368,   0.37239368,
#          0.37239368,  -5.39518256,   0.37239368,   0.37239368,
#         -5.39518256,   0.37239368,  -5.39518256,  -5.39518256,
#         -5.39518256,  -5.39518256,  -5.39518256,  -5.39518256,
#          0.37239368,   0.37239368,  -5.39518256,   0.37239368,
#         -5.39518256,  -5.39518256,  -5.39518256,   0.37239368,
#          0.37239368,   0.37239368,   0.37239368,   0.37239368,
#         10.81603089,   0.37239368,   0.37239368,   0.37239368,
#          0.37239368,   0.37239368,   0.37239368,  -5.39518256,
#         -5.39518256,  -5.39518256,   0.37239368,   0.37239368,
#          0.37239368,   0.37239368,  -5.39518256,  10.81603089,
#          0.37239368,   0.37239368,   0.37239368,   0.37239368,
# ...

# %%
guess += tree.predict(X)

# %%
guess
# Out:
# array([22.9052    , 22.9052    , 33.34883721, 33.34883721, 33.34883721,
#        22.9052    , 22.9052    , 17.13762376, 17.13762376, 17.13762376,
#        17.13762376, 22.9052    , 17.13762376, 22.9052    , 22.9052    ,
#        22.9052    , 22.9052    , 17.13762376, 22.9052    , 22.9052    ,
#        17.13762376, 22.9052    , 17.13762376, 17.13762376, 17.13762376,
#        17.13762376, 17.13762376, 17.13762376, 22.9052    , 22.9052    ,
#        17.13762376, 22.9052    , 17.13762376, 17.13762376, 17.13762376,
#        22.9052    , 22.9052    , 22.9052    , 22.9052    , 22.9052    ,
#        33.34883721, 22.9052    , 22.9052    , 22.9052    , 22.9052    ,
#        22.9052    , 22.9052    , 17.13762376, 17.13762376, 17.13762376,
#        22.9052    , 22.9052    , 22.9052    , 22.9052    , 17.13762376,
#        33.34883721, 22.9052    , 22.9052    , 22.9052    , 22.9052    ,
#        22.9052    , 17.13762376, 22.9052    , 22.9052    , 33.34883721,
# ...

# %%
gradient = y - guess

# %%
tree.fit(X, gradient)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
guess += tree.predict(X)

# %%
y[:5]
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: PRICE, dtype: float64

# %%
guess[:5]
# Out:
# array([28.36134711, 22.53819628, 33.10275194, 33.10275194, 33.10275194])

# %%
gradient = y - guess

# %%
tree.fit(X, gradient)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
guess += tree.predict(X)

# %%
guess
# Out:
# array([28.65131748, 22.82816666, 33.39272232, 35.7751506 , 35.7751506 ,
#        26.67962533, 20.33077957, 19.28382244, 17.61795532, 19.28382244,
#        19.28382244, 20.33077957, 19.28382244, 18.96359899, 15.49431154,
#        18.96359899, 22.93001646, 14.4473544 , 18.96359899, 18.96359899,
#        14.4473544 , 15.49431154, 14.4473544 , 14.4473544 , 14.4473544 ,
#        14.4473544 , 14.4473544 , 14.4473544 , 17.99169862, 17.99169862,
#        14.4473544 , 15.49431154, 14.4473544 , 14.4473544 , 14.4473544 ,
#        20.33077957, 20.33077957, 20.33077957, 20.33077957, 28.65131748,
#        33.39272232, 28.65131748, 24.29719704, 24.29719704, 20.33077957,
#        20.33077957, 20.33077957, 19.28382244, 17.61795532, 19.28382244,
#        20.33077957, 22.82816666, 24.29719704, 20.33077957, 19.27740088,
#        33.39272232, 24.29719704, 28.65131748, 24.29719704, 20.33077957,
#        20.33077957, 19.28382244, 24.29719704, 22.82816666, 35.65423215,
# ...

# %%
learning_rate = 0.1

# %%
guess += tree.predict(X)*learning_rate

# %%
guess
# Out:
# array([28.90696182, 22.50149591, 33.07814341, 33.07814341, 33.07814341,
#        24.11742933, 19.75437011, 19.17947489, 19.17947489, 19.17947489,
#        19.17947489, 19.75437011, 19.17947489, 19.75437011, 19.75437011,
#        19.75437011, 24.11742933, 19.17947489, 19.75437011, 19.75437011,
#        19.17947489, 19.75437011, 19.17947489, 19.17947489, 19.17947489,
#        19.17947489, 19.17947489, 19.17947489, 22.50149591, 22.50149591,
#        19.17947489, 19.75437011, 19.17947489, 19.17947489, 19.17947489,
#        19.75437011, 19.75437011, 19.75437011, 19.75437011, 28.90696182,
#        33.07814341, 28.90696182, 24.11742933, 24.11742933, 19.75437011,
#        19.75437011, 19.75437011, 19.17947489, 19.17947489, 19.17947489,
#        19.75437011, 22.50149591, 24.11742933, 19.75437011, 19.17947489,
#        33.07814341, 24.11742933, 28.90696182, 24.11742933, 19.75437011,
#        19.75437011, 19.17947489, 24.11742933, 22.50149591, 32.94513312,
# ...
