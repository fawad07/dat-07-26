# %%
import pandas as pd

# %%
# your answer here
reservations = pd.read_csv('../data/restaurant_data/air_reserve.csv')
store_info   = pd.read_csv('../data/restaurant_data/air_store_info.csv')
visits       = pd.read_csv('../data/restaurant_data/air_visit_data.csv')
date_info     = pd.read_csv('../data/restaurant_data/date_info.csv')

# %%
reservations
# Out:
#                air_store_id       visit_datetime     reserve_datetime  \
# 0      air_877f79706adbfb06  2016-01-01 19:00:00  2016-01-01 16:00:00
# 1      air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 2      air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 3      air_877f79706adbfb06  2016-01-01 20:00:00  2016-01-01 16:00:00
# 4      air_db80363d35f10926  2016-01-01 20:00:00  2016-01-01 01:00:00
# ...                     ...                  ...                  ...
# 92373  air_db4b38ebe7a7ceff  2017-05-29 18:00:00  2017-04-17 19:00:00
# 92374  air_1033310359ceeac1  2017-05-30 23:00:00  2017-04-19 17:00:00
# 92375  air_877f79706adbfb06  2017-05-31 20:00:00  2017-04-12 23:00:00
# 92376  air_900d755ebd2f7bbd  2017-05-31 20:00:00  2017-04-19 16:00:00
# 92377  air_3cad29d1a23209d2  2017-05-31 21:00:00  2017-04-22 10:00:00
#
#        reserve_visitors
# 0                     1
# 1                     3
# 2                     6
# 3                     2
# ...

# %%
store_info
# Out:
#              air_store_id         air_genre_name  \
# 0    air_0f0cdeee6c9bf3d7         Italian/French
# 1    air_7cc17a324ae5c7dc         Italian/French
# 2    air_fee8dcf4d619598e         Italian/French
# 3    air_a17f0778617c76e2         Italian/French
# 4    air_83db5aff8f50478e         Italian/French
# ..                    ...                    ...
# 824  air_9bf595ef095572fb  International cuisine
# 825  air_764f71040a413d4d                  Asian
# 826  air_10bbe8acd943d8f6                  Asian
# 827  air_7514d90009613cd6          Karaoke/Party
# 828  air_c8fe396d6c46275d          Karaoke/Party
#
#                              air_area_name   latitude   longitude
# 0             Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197852
# 1             Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197852
# 2             Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197852
# 3             Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197852
# ...

# %%
visits
# Out:
#                 air_store_id  visit_date  visitors
# 0       air_ba937bf13d40fb24  2016-01-13        25
# 1       air_ba937bf13d40fb24  2016-01-14        32
# 2       air_ba937bf13d40fb24  2016-01-15        29
# 3       air_ba937bf13d40fb24  2016-01-16        22
# 4       air_ba937bf13d40fb24  2016-01-18         6
# ...                      ...         ...       ...
# 252103  air_24e8414b9b07decb  2017-04-18         6
# 252104  air_24e8414b9b07decb  2017-04-19         6
# 252105  air_24e8414b9b07decb  2017-04-20         7
# 252106  air_24e8414b9b07decb  2017-04-21         8
# 252107  air_24e8414b9b07decb  2017-04-22         5
#
# [252108 rows x 3 columns]

# %%
date_info
# Out:
#     calendar_date day_of_week  holiday_flg
# 0      2016-01-01      Friday            1
# 1      2016-01-02    Saturday            1
# 2      2016-01-03      Sunday            1
# 3      2016-01-04      Monday            0
# 4      2016-01-05     Tuesday            0
# ..            ...         ...          ...
# 512    2017-05-27    Saturday            0
# 513    2017-05-28      Sunday            0
# 514    2017-05-29      Monday            0
# 515    2017-05-30     Tuesday            0
# 516    2017-05-31   Wednesday            0
#
# [517 rows x 3 columns]

# %%
master = visits.merge(store_info, on='air_store_id', how='left')

# %%
master
# Out:
#                 air_store_id  visit_date  visitors air_genre_name  \
# 0       air_ba937bf13d40fb24  2016-01-13        25     Dining bar
# 1       air_ba937bf13d40fb24  2016-01-14        32     Dining bar
# 2       air_ba937bf13d40fb24  2016-01-15        29     Dining bar
# 3       air_ba937bf13d40fb24  2016-01-16        22     Dining bar
# 4       air_ba937bf13d40fb24  2016-01-18         6     Dining bar
# ...                      ...         ...       ...            ...
# 252103  air_24e8414b9b07decb  2017-04-18         6          Other
# 252104  air_24e8414b9b07decb  2017-04-19         6          Other
# 252105  air_24e8414b9b07decb  2017-04-20         7          Other
# 252106  air_24e8414b9b07decb  2017-04-21         8          Other
# 252107  air_24e8414b9b07decb  2017-04-22         5          Other
#
#                        air_area_name   latitude   longitude
# 0       Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# ...

# %%
date_info
# Out:
#     calendar_date day_of_week  holiday_flg
# 0      2016-01-01      Friday            1
# 1      2016-01-02    Saturday            1
# 2      2016-01-03      Sunday            1
# 3      2016-01-04      Monday            0
# 4      2016-01-05     Tuesday            0
# ..            ...         ...          ...
# 512    2017-05-27    Saturday            0
# 513    2017-05-28      Sunday            0
# 514    2017-05-29      Monday            0
# 515    2017-05-30     Tuesday            0
# 516    2017-05-31   Wednesday            0
#
# [517 rows x 3 columns]

# %%
master
# Out:
#                 air_store_id  visit_date  visitors air_genre_name  \
# 0       air_ba937bf13d40fb24  2016-01-13        25     Dining bar
# 1       air_ba937bf13d40fb24  2016-01-14        32     Dining bar
# 2       air_ba937bf13d40fb24  2016-01-15        29     Dining bar
# 3       air_ba937bf13d40fb24  2016-01-16        22     Dining bar
# 4       air_ba937bf13d40fb24  2016-01-18         6     Dining bar
# ...                      ...         ...       ...            ...
# 252103  air_24e8414b9b07decb  2017-04-18         6          Other
# 252104  air_24e8414b9b07decb  2017-04-19         6          Other
# 252105  air_24e8414b9b07decb  2017-04-20         7          Other
# 252106  air_24e8414b9b07decb  2017-04-21         8          Other
# 252107  air_24e8414b9b07decb  2017-04-22         5          Other
#
#                        air_area_name   latitude   longitude
# 0       Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# ...

# %%
master = master.merge(date_info, left_on='visit_date', right_on='calendar_date', how='left')

# %%
master
# Out:
#                 air_store_id  visit_date  visitors air_genre_name  \
# 0       air_ba937bf13d40fb24  2016-01-13        25     Dining bar
# 1       air_ba937bf13d40fb24  2016-01-14        32     Dining bar
# 2       air_ba937bf13d40fb24  2016-01-15        29     Dining bar
# 3       air_ba937bf13d40fb24  2016-01-16        22     Dining bar
# 4       air_ba937bf13d40fb24  2016-01-18         6     Dining bar
# ...                      ...         ...       ...            ...
# 252103  air_24e8414b9b07decb  2017-04-18         6          Other
# 252104  air_24e8414b9b07decb  2017-04-19         6          Other
# 252105  air_24e8414b9b07decb  2017-04-20         7          Other
# 252106  air_24e8414b9b07decb  2017-04-21         8          Other
# 252107  air_24e8414b9b07decb  2017-04-22         5          Other
#
#                        air_area_name   latitude   longitude calendar_date  \
# 0       Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599    2016-01-13
# ...

# %%
reservations
# Out:
#                air_store_id       visit_datetime     reserve_datetime  \
# 0      air_877f79706adbfb06  2016-01-01 19:00:00  2016-01-01 16:00:00
# 1      air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 2      air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 3      air_877f79706adbfb06  2016-01-01 20:00:00  2016-01-01 16:00:00
# 4      air_db80363d35f10926  2016-01-01 20:00:00  2016-01-01 01:00:00
# ...                     ...                  ...                  ...
# 92373  air_db4b38ebe7a7ceff  2017-05-29 18:00:00  2017-04-17 19:00:00
# 92374  air_1033310359ceeac1  2017-05-30 23:00:00  2017-04-19 17:00:00
# 92375  air_877f79706adbfb06  2017-05-31 20:00:00  2017-04-12 23:00:00
# 92376  air_900d755ebd2f7bbd  2017-05-31 20:00:00  2017-04-19 16:00:00
# 92377  air_3cad29d1a23209d2  2017-05-31 21:00:00  2017-04-22 10:00:00
#
#        reserve_visitors
# 0                     1
# 1                     3
# 2                     6
# 3                     2
# ...

# %%
master
# Out:
#                 air_store_id  visit_date  visitors air_genre_name  \
# 0       air_ba937bf13d40fb24  2016-01-13        25     Dining bar
# 1       air_ba937bf13d40fb24  2016-01-14        32     Dining bar
# 2       air_ba937bf13d40fb24  2016-01-15        29     Dining bar
# 3       air_ba937bf13d40fb24  2016-01-16        22     Dining bar
# 4       air_ba937bf13d40fb24  2016-01-18         6     Dining bar
# ...                      ...         ...       ...            ...
# 252103  air_24e8414b9b07decb  2017-04-18         6          Other
# 252104  air_24e8414b9b07decb  2017-04-19         6          Other
# 252105  air_24e8414b9b07decb  2017-04-20         7          Other
# 252106  air_24e8414b9b07decb  2017-04-21         8          Other
# 252107  air_24e8414b9b07decb  2017-04-22         5          Other
#
#                        air_area_name   latitude   longitude calendar_date  \
# 0       Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599    2016-01-13
# ...

# %%
reservations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92378 entries, 0 to 92377
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   air_store_id      92378 non-null  object
#  1   visit_datetime    92378 non-null  object
#  2   reserve_datetime  92378 non-null  object
#  3   reserve_visitors  92378 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 2.8+ MB

# %%
reservations['visit_datetime'] = pd.to_datetime(reservations['visit_datetime'])

# %%
reservations
# Out:
#                air_store_id      visit_datetime     reserve_datetime  \
# 0      air_877f79706adbfb06 2016-01-01 19:00:00  2016-01-01 16:00:00
# 1      air_db4b38ebe7a7ceff 2016-01-01 19:00:00  2016-01-01 19:00:00
# 2      air_db4b38ebe7a7ceff 2016-01-01 19:00:00  2016-01-01 19:00:00
# 3      air_877f79706adbfb06 2016-01-01 20:00:00  2016-01-01 16:00:00
# 4      air_db80363d35f10926 2016-01-01 20:00:00  2016-01-01 01:00:00
# ...                     ...                 ...                  ...
# 92373  air_db4b38ebe7a7ceff 2017-05-29 18:00:00  2017-04-17 19:00:00
# 92374  air_1033310359ceeac1 2017-05-30 23:00:00  2017-04-19 17:00:00
# 92375  air_877f79706adbfb06 2017-05-31 20:00:00  2017-04-12 23:00:00
# 92376  air_900d755ebd2f7bbd 2017-05-31 20:00:00  2017-04-19 16:00:00
# 92377  air_3cad29d1a23209d2 2017-05-31 21:00:00  2017-04-22 10:00:00
#
#        reserve_visitors
# 0                     1
# 1                     3
# 2                     6
# 3                     2
# ...

# %%
reservations['visit_datetime'] = reservations['visit_datetime'].dt.date

# %%
reservations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92378 entries, 0 to 92377
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   air_store_id      92378 non-null  object
#  1   visit_datetime    92378 non-null  object
#  2   reserve_datetime  92378 non-null  object
#  3   reserve_visitors  92378 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 2.8+ MB

# %%
reservations = reservations.groupby(['air_store_id', 'visit_datetime'])['reserve_visitors'].sum().reset_index()

# %%
reservations
# Out:
#                air_store_id visit_datetime  reserve_visitors
# 0      air_00a91d42b08b08d9     2016-10-31                 2
# 1      air_00a91d42b08b08d9     2016-12-05                 9
# 2      air_00a91d42b08b08d9     2016-12-14                18
# 3      air_00a91d42b08b08d9     2016-12-17                 2
# 4      air_00a91d42b08b08d9     2016-12-20                 4
# ...                     ...            ...               ...
# 29825  air_fea5dc9594450608     2017-04-22                 2
# 29826  air_fea5dc9594450608     2017-04-25                 2
# 29827  air_fea5dc9594450608     2017-04-28                 3
# 29828  air_fea5dc9594450608     2017-05-20                 6
# 29829  air_fee8dcf4d619598e     2017-01-09                 5
#
# [29830 rows x 3 columns]

# %%
reservations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29830 entries, 0 to 29829
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   air_store_id      29830 non-null  object
#  1   visit_datetime    29830 non-null  object
#  2   reserve_visitors  29830 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 699.3+ KB

# %%
reservations['visit_datetime'] = pd.to_datetime(reservations['visit_datetime'])
master['visit_date'] = pd.to_datetime(master['visit_date'])

# %%
master
# Out:
#                 air_store_id visit_date  visitors air_genre_name  \
# 0       air_ba937bf13d40fb24 2016-01-13        25     Dining bar
# 1       air_ba937bf13d40fb24 2016-01-14        32     Dining bar
# 2       air_ba937bf13d40fb24 2016-01-15        29     Dining bar
# 3       air_ba937bf13d40fb24 2016-01-16        22     Dining bar
# 4       air_ba937bf13d40fb24 2016-01-18         6     Dining bar
# ...                      ...        ...       ...            ...
# 252103  air_24e8414b9b07decb 2017-04-18         6          Other
# 252104  air_24e8414b9b07decb 2017-04-19         6          Other
# 252105  air_24e8414b9b07decb 2017-04-20         7          Other
# 252106  air_24e8414b9b07decb 2017-04-21         8          Other
# 252107  air_24e8414b9b07decb 2017-04-22         5          Other
#
#                        air_area_name   latitude   longitude calendar_date  \
# 0       Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599    2016-01-13
# ...

# %%
reservations
# Out:
#                air_store_id visit_datetime  reserve_visitors
# 0      air_00a91d42b08b08d9     2016-10-31                 2
# 1      air_00a91d42b08b08d9     2016-12-05                 9
# 2      air_00a91d42b08b08d9     2016-12-14                18
# 3      air_00a91d42b08b08d9     2016-12-17                 2
# 4      air_00a91d42b08b08d9     2016-12-20                 4
# ...                     ...            ...               ...
# 29825  air_fea5dc9594450608     2017-04-22                 2
# 29826  air_fea5dc9594450608     2017-04-25                 2
# 29827  air_fea5dc9594450608     2017-04-28                 3
# 29828  air_fea5dc9594450608     2017-05-20                 6
# 29829  air_fee8dcf4d619598e     2017-01-09                 5
#
# [29830 rows x 3 columns]

# %%
master.shape[0] - 224088
# Out:
# 28020

# %%
master.merge(reservations, how='left', left_on=['air_store_id', 'visit_date'], right_on=['air_store_id', 'visit_datetime']).isnull().sum()
# Out:
# air_store_id             0
# visit_date               0
# visitors                 0
# air_genre_name           0
# air_area_name            0
# latitude                 0
# longitude                0
# calendar_date            0
# day_of_week              0
# holiday_flg              0
# visit_datetime      224044
# reserve_visitors    224044
# dtype: int64

# %%
df = pd.read_csv('../data/restaurant_data/master.csv', parse_dates=['visit_date'])

# %%
df
# Out:
#                           id visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday
# ...                      ...        ...       ...           ...         ...
# 252103  air_a17f0778617c76e2 2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2 2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2 2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2 2017-03-20        31    2017-03-20      Monday
# 252107  air_a17f0778617c76e2 2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252108 entries, 0 to 252107
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                252108 non-null  object
#  1   visit_date        252108 non-null  datetime64[ns]
#  2   visitors          252108 non-null  int64
#  3   calendar_date     252108 non-null  object
#  4   day_of_week       252108 non-null  object
#  5   holiday           252108 non-null  int64
#  6   genre             252108 non-null  object
#  7   area              252108 non-null  object
#  8   latitude          252108 non-null  float64
#  9   longitude         252108 non-null  float64
#  10  reserve_visitors  108394 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(5)
# memory usage: 21.2+ MB

# %%
df['visit_date'].dt.day
# Out:
# 0         13
# 1         14
# 2         15
# 3         16
# 4         18
#           ..
# 252103    21
# 252104    22
# 252105    26
# 252106    20
# 252107     9
# Name: visit_date, Length: 252108, dtype: int64

# %%
df['visitors']
# Out:
# 0         25
# 1         32
# 2         29
# 3         22
# 4          6
#           ..
# 252103    49
# 252104    60
# 252105    69
# 252106    31
# 252107    26
# Name: visitors, Length: 252108, dtype: int64

# %%
df['visitors'].shift(7).head(10)
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7    25.0
# 8    32.0
# 9    29.0
# Name: visitors, dtype: float64

# %%
df['yesterday'] = df['visitors'].shift()

# %%
df['yesterday'] = df.groupby('id')['visitors'].shift(7)

# %%
df.loc[df.id == 'air_a17f0778617c76e2', :]
# Out:
#                           id visit_date  visitors calendar_date day_of_week  \
# 252061  air_a17f0778617c76e2 2017-03-07        20    2017-03-07     Tuesday
# 252062  air_a17f0778617c76e2 2017-03-08        31    2017-03-08   Wednesday
# 252063  air_a17f0778617c76e2 2017-03-09        18    2017-03-09    Thursday
# 252064  air_a17f0778617c76e2 2017-03-10        71    2017-03-10      Friday
# 252065  air_a17f0778617c76e2 2017-03-11        98    2017-03-11    Saturday
# 252066  air_a17f0778617c76e2 2017-03-12        19    2017-03-12      Sunday
# 252067  air_a17f0778617c76e2 2017-03-13        24    2017-03-13      Monday
# 252068  air_a17f0778617c76e2 2017-03-14        22    2017-03-14     Tuesday
# 252069  air_a17f0778617c76e2 2017-03-15        47    2017-03-15   Wednesday
# 252070  air_a17f0778617c76e2 2017-03-16        17    2017-03-16    Thursday
# 252071  air_a17f0778617c76e2 2017-03-17        65    2017-03-17      Friday
# ...

# %%
df.tail()
# Out:
#                           id visit_date  visitors calendar_date day_of_week  \
# 252103  air_a17f0778617c76e2 2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2 2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2 2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2 2017-03-20        31    2017-03-20      Monday
# 252107  air_a17f0778617c76e2 2017-04-09        26    2017-04-09      Sunday
#
#         holiday           genre                          area   latitude  \
# 252103        0  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124
# 252104        0  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124
# 252105        0  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124
# 252106        1  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124
# 252107        0  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124
#
#          longitude  reserve_visitors  yesterday
# ...

# %%
df['visitors'].diff(7).head(10)
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7    -4.0
# 8   -14.0
# 9    -3.0
# Name: visitors, dtype: float64

# %%
df['visitors'].head(10)
# Out:
# 0    25
# 1    32
# 2    29
# 3    22
# 4     6
# 5     9
# 6    31
# 7    21
# 8    18
# 9    26
# Name: visitors, dtype: int64

# %%
df['visitors'].pct_change(7)
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#             ...
# 252103   -0.443182
# 252104   -0.016393
# 252105    1.653846
# 252106    0.631579
# 252107    1.363636
# Name: visitors, Length: 252108, dtype: float64

# %%
df['visitors'].rolling(5).sum()
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4         114.0
#           ...
# 252103    126.0
# 252104    167.0
# 252105    225.0
# 252106    231.0
# 252107    235.0
# Name: visitors, Length: 252108, dtype: float64

# %%
df['visitors'][2:5].mean()
# Out:
# 19.0

# %%
df.groupby('id')['visitors'].rolling(5).mean().values
# Out:
# array([nan, nan, nan, ..., 4. , 2.4, 3.2])

# %%
df.head(10)
# Out:
#                      id visit_date  visitors calendar_date day_of_week  \
# 0  air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday
# 1  air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday
# 2  air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday
# 3  air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday
# 4  air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday
# 5  air_ba937bf13d40fb24 2016-01-19         9    2016-01-19     Tuesday
# 6  air_ba937bf13d40fb24 2016-01-20        31    2016-01-20   Wednesday
# 7  air_ba937bf13d40fb24 2016-01-21        21    2016-01-21    Thursday
# 8  air_ba937bf13d40fb24 2016-01-22        18    2016-01-22      Friday
# 9  air_ba937bf13d40fb24 2016-01-23        26    2016-01-23    Saturday
#
#    holiday       genre                          area   latitude   longitude  \
# 0        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# ...

# %%
df['five'] = df.groupby('id')['visitors'].sum()

# %%
df.set_index(['id', 'visit_date']).groupby(level=)
# Out:
#                                  visitors calendar_date day_of_week  holiday  \
# id                   visit_date
# air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday        0
#                      2016-01-14        32    2016-01-14    Thursday        0
#                      2016-01-15        29    2016-01-15      Friday        0
#                      2016-01-16        22    2016-01-16    Saturday        0
#                      2016-01-18         6    2016-01-18      Monday        0
# ...                                   ...           ...         ...      ...
# air_a17f0778617c76e2 2017-04-21        49    2017-04-21      Friday        0
#                      2017-04-22        60    2017-04-22    Saturday        0
#                      2017-03-26        69    2017-03-26      Sunday        0
#                      2017-03-20        31    2017-03-20      Monday        1
#                      2017-04-09        26    2017-04-09      Sunday        0
#
# ...
