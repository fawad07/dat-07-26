# %%
import pandas as pd

# %%
df = pd.read_csv('../data/restaurant_data/master.csv', parse_dates=['visit_date'])

# %%
df
# Out:
#                           id visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday
# ...                      ...        ...       ...           ...         ...
# 252103  air_a17f0778617c76e2 2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2 2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2 2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2 2017-03-20        31    2017-03-20      Monday
# 252107  air_a17f0778617c76e2 2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
idx_cols = df.columns[:5]

# %%
idx_cols
# Out:
# Index(['id', 'visit_date', 'visitors', 'calendar_date', 'day_of_week'], dtype='object')

# %%
df.loc[3, idx_cols]
# Out:
# id               air_ba937bf13d40fb24
# visit_date        2016-01-16 00:00:00
# visitors                           22
# calendar_date              2016-01-16
# day_of_week                  Saturday
# Name: 3, dtype: object

# %%
df.iloc[3, :5]
# Out:
# id               air_ba937bf13d40fb24
# visit_date        2016-01-16 00:00:00
# visitors                           22
# calendar_date              2016-01-16
# day_of_week                  Saturday
# Name: 3, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=252108, step=1)

# %%
df.loc[:, df.isnull().sum() > 0]
# Out:
#         reserve_visitors
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 252103               6.0
# 252104              37.0
# 252105              35.0
# 252106               3.0
# 252107              32.0
#
# [252108 rows x 1 columns]

# %%
df.loc[df['visitors'] > 25, :]
# Out:
#                           id visit_date  visitors calendar_date day_of_week  \
# 1       air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday
# 6       air_ba937bf13d40fb24 2016-01-20        31    2016-01-20   Wednesday
# 9       air_ba937bf13d40fb24 2016-01-23        26    2016-01-23    Saturday
# 14      air_ba937bf13d40fb24 2016-01-29        26    2016-01-29      Friday
# ...                      ...        ...       ...           ...         ...
# 252103  air_a17f0778617c76e2 2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2 2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2 2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2 2017-03-20        31    2017-03-20      Monday
# 252107  air_a17f0778617c76e2 2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
df.set_index('id', inplace=True)

# %%
df.loc['air_ba937bf13d40fb24']
# Out:
#                      visit_date  visitors calendar_date day_of_week  holiday  \
# id
# air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday        0
# air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday        0
# air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday        0
# air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday        0
# air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday        0
# ...                         ...       ...           ...         ...      ...
# air_ba937bf13d40fb24 2017-04-18        11    2017-04-18     Tuesday        0
# air_ba937bf13d40fb24 2017-04-19        11    2017-04-19   Wednesday        0
# air_ba937bf13d40fb24 2017-04-20        14    2017-04-20    Thursday        0
# air_ba937bf13d40fb24 2017-04-21        40    2017-04-21      Friday        0
# air_ba937bf13d40fb24 2017-04-22        23    2017-04-22    Saturday        0
#
# ...

# %%
df.median()
# Out:
# <ipython-input-35-6d467abf240d>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.median()
# visitors             17.000000
# holiday               0.000000
# latitude             35.658068
# longitude           139.670038
# reserve_visitors     10.000000
# dtype: float64

# %%
import numpy as np

np.median(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-3cad83a15947> in <module>
#       1 import numpy as np
#       2
# ----> 3 np.median(df)
#
# <__array_function__ internals> in median(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python38\site-packages\numpy\lib\function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3518
#    3519     """
# -> 3520     r, k = _ureduce(a, func=_median, axis=axis, out=out,
#    3521                     overwrite_input=overwrite_input)
#    3522     if keepdims:
#
# ~\AppData\Roaming\Python\Python38\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    3427         keepdim = (1,) * a.ndim
#    3428
# -> 3429     r = func(a, **kwargs)
#    3430     return r, keepdim
#    3431
#
# ...

# %%
np.mean(df.select_dtypes(include=np.number))
# Out:
# visitors             20.973761
# holiday               0.050673
# latitude             35.613121
# longitude           137.357865
# reserve_visitors     16.699808
# dtype: float64

# %%
df.isnull().sum()
# Out:
# visit_date               0
# visitors                 0
# calendar_date            0
# day_of_week              0
# holiday                  0
# genre                    0
# area                     0
# latitude                 0
# longitude                0
# reserve_visitors    143714
# dtype: int64

# %%
df.groupby('genre').agg([np.mean, np.sum, np.std, get_nulls])
# Out:
#                                visitors                                \
#                                    mean      sum        std get_nulls
# genre
# Asian                         38.747664    20730  18.839800         0
# Bar/Cocktail                  13.308733   334515  14.144398         0
# Cafe/Sweets                   22.606360  1192802  17.300965         0
# Creative cuisine              23.600052    91285  18.333592         0
# Dining bar                    18.723532   640195  16.000680         0
# International cuisine         25.209677     9378  12.293978         0
# Italian/French                22.582953   677737  17.034393         0
# Izakaya                       23.082850  1432337  17.021357         0
# Japanese food                 19.551440   367352  14.844370         0
# Karaoke/Party                 29.992248    15476  35.419154         0
# Okonomiyaki/Monja/Teppanyaki  22.611171    83797  18.376455         0
# ...

# %%
df['visit_date'].isnull().sum()
# Out:
# 0

# %%
def get_nulls(series):
    return series.isnull().sum()

# %%
get_nulls(df['genre'])
# Out:
# 0

# %%
df[df['genre'] == 'Asian']['reserve_visitors'].isnull().sum()
# Out:
# 292

# %%
df['new_col'] = 1

# %%
df
# Out:
#                      visit_date  visitors calendar_date day_of_week  holiday  \
# id
# air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday        0
# air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday        0
# air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday        0
# air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday        0
# air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday        0
# ...                         ...       ...           ...         ...      ...
# air_a17f0778617c76e2 2017-04-21        49    2017-04-21      Friday        0
# air_a17f0778617c76e2 2017-04-22        60    2017-04-22    Saturday        0
# air_a17f0778617c76e2 2017-03-26        69    2017-03-26      Sunday        0
# air_a17f0778617c76e2 2017-03-20        31    2017-03-20      Monday        1
# air_a17f0778617c76e2 2017-04-09        26    2017-04-09      Sunday        0
#
# ...

# %%
df['new_col'] = list(range(0, len(df)))

# %%
df
# Out:
#                      visit_date  visitors calendar_date day_of_week  holiday  \
# id
# air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday        0
# air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday        0
# air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday        0
# air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday        0
# air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday        0
# ...                         ...       ...           ...         ...      ...
# air_a17f0778617c76e2 2017-04-21        49    2017-04-21      Friday        0
# air_a17f0778617c76e2 2017-04-22        60    2017-04-22    Saturday        0
# air_a17f0778617c76e2 2017-03-26        69    2017-03-26      Sunday        0
# air_a17f0778617c76e2 2017-03-20        31    2017-03-20      Monday        1
# air_a17f0778617c76e2 2017-04-09        26    2017-04-09      Sunday        0
#
# ...

# %%
df['visitors'] - df['visitors'].mean()
# Out:
# id
# air_ba937bf13d40fb24     4.026239
# air_ba937bf13d40fb24    11.026239
# air_ba937bf13d40fb24     8.026239
# air_ba937bf13d40fb24     1.026239
# air_ba937bf13d40fb24   -14.973761
#                           ...
# air_a17f0778617c76e2    28.026239
# air_a17f0778617c76e2    39.026239
# air_a17f0778617c76e2    48.026239
# air_a17f0778617c76e2    10.026239
# air_a17f0778617c76e2     5.026239
# Name: visitors, Length: 252108, dtype: float64

# %%
df['Part_of_Week'] = np.where((df['day_of_week'] == 'Saturday') | (df['day_of_week'] == 'Sunday'), 'Weekend', 'Weekday')

# %%
df
# Out:
#                      visit_date  visitors calendar_date day_of_week  holiday  \
# id
# air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday        0
# air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday        0
# air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday        0
# air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday        0
# air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday        0
# ...                         ...       ...           ...         ...      ...
# air_a17f0778617c76e2 2017-04-21        49    2017-04-21      Friday        0
# air_a17f0778617c76e2 2017-04-22        60    2017-04-22    Saturday        0
# air_a17f0778617c76e2 2017-03-26        69    2017-03-26      Sunday        0
# air_a17f0778617c76e2 2017-03-20        31    2017-03-20      Monday        1
# air_a17f0778617c76e2 2017-04-09        26    2017-04-09      Sunday        0
#
# ...

# %%
df = df.drop('new_col', axis=1)

# %%
df.reset_index()
# Out:
#                           id visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday
# ...                      ...        ...       ...           ...         ...
# 252103  air_a17f0778617c76e2 2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2 2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2 2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2 2017-03-20        31    2017-03-20      Monday
# 252107  air_a17f0778617c76e2 2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
df.drop('id', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-5f2ae31dcd7e> in <module>
# ----> 1 df.drop('id', axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df.drop_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-885e1e13d196> in <module>
# ----> 1 df.drop_index()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'drop_index'

# %%
df.droplevel(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-f0e042bcd58e> in <module>
# ----> 1 df.droplevel(0)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in droplevel(self, level, axis)
#     654         """
#     655         labels = self._get_axis(axis)
# --> 656         new_labels = labels.droplevel(level)
#     657         result = self.set_axis(new_labels, axis=axis, inplace=False)
#     658         return result
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in droplevel(self, level)
#    1503             return self
#    1504         if len(level) >= self.nlevels:
# -> 1505             raise ValueError(
#    1506                 f"Cannot remove {len(level)} levels from an index with {self.nlevels} "
#    1507                 "levels: at least one level must be left."
#
# ...

# %%
df.reset_index(drop=True)
# Out:
#        visit_date  visitors calendar_date day_of_week  holiday  \
# 0      2016-01-13        25    2016-01-13   Wednesday        0
# 1      2016-01-14        32    2016-01-14    Thursday        0
# 2      2016-01-15        29    2016-01-15      Friday        0
# 3      2016-01-16        22    2016-01-16    Saturday        0
# 4      2016-01-18         6    2016-01-18      Monday        0
# ...           ...       ...           ...         ...      ...
# 252103 2017-04-21        49    2017-04-21      Friday        0
# 252104 2017-04-22        60    2017-04-22    Saturday        0
# 252105 2017-03-26        69    2017-03-26      Sunday        0
# 252106 2017-03-20        31    2017-03-20      Monday        1
# 252107 2017-04-09        26    2017-04-09      Sunday        0
#
#                  genre                          area   latitude   longitude  \
# 0           Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# ...

# %%
df['visitors'] < 18
# Out:
# id
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24     True
#                         ...
# air_a17f0778617c76e2    False
# air_a17f0778617c76e2    False
# air_a17f0778617c76e2    False
# air_a17f0778617c76e2    False
# air_a17f0778617c76e2    False
# Name: visitors, Length: 252108, dtype: bool

# %%
df['visitors'] > 30
# Out:
# id
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24     True
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24    False
#                         ...
# air_a17f0778617c76e2     True
# air_a17f0778617c76e2     True
# air_a17f0778617c76e2     True
# air_a17f0778617c76e2     True
# air_a17f0778617c76e2    False
# Name: visitors, Length: 252108, dtype: bool

# %%
conditions = [
    df['visitors'] < 18, 
    df['visitors'].between(18, 30),
    df['visitors'] > 30
]

results    = [
        'low traffic',
        'medium traffic',
         'high traffic'
]

df['traffic'] = np.select(conditions, results, 'Other')

# %%
df
# Out:
#                      visit_date  visitors calendar_date day_of_week  holiday  \
# id
# air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday        0
# air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday        0
# air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday        0
# air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday        0
# air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday        0
# ...                         ...       ...           ...         ...      ...
# air_a17f0778617c76e2 2017-04-21        49    2017-04-21      Friday        0
# air_a17f0778617c76e2 2017-04-22        60    2017-04-22    Saturday        0
# air_a17f0778617c76e2 2017-03-26        69    2017-03-26      Sunday        0
# air_a17f0778617c76e2 2017-03-20        31    2017-03-20      Monday        1
# air_a17f0778617c76e2 2017-04-09        26    2017-04-09      Sunday        0
#
# ...

# %%
df['visit_date'] - df['visit_date'].min()
# Out:
# id
# air_ba937bf13d40fb24    12 days
# air_ba937bf13d40fb24    13 days
# air_ba937bf13d40fb24    14 days
# air_ba937bf13d40fb24    15 days
# air_ba937bf13d40fb24    17 days
#                          ...
# air_a17f0778617c76e2   476 days
# air_a17f0778617c76e2   477 days
# air_a17f0778617c76e2   450 days
# air_a17f0778617c76e2   444 days
# air_a17f0778617c76e2   464 days
# Name: visit_date, Length: 252108, dtype: timedelta64[ns]

# %%
df['reserve_visitors'].quantile(0, .25)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-7565c7b8e44d> in <module>
# ----> 1 df['reserve_visitors'].quantile(0, .25)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in quantile(self, q, interpolation)
#    2259         df = self.to_frame()
#    2260
# -> 2261         result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2262         if result.ndim == 2:
#    2263             result = result.iloc[:, 0]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in quantile(self, q, axis, numeric_only, interpolation)
#    9057             return self._constructor_sliced([], index=cols, name=q, dtype=np.float64)
#    9058
# -> 9059         result = data._mgr.quantile(
#    9060             qs=q, axis=1, interpolation=interpolation, transposed=is_transposed
#    9061         )
#
# ...

# %%
df['reserve_visitors'] < df['reserve_visitors'].quantile(.25)
# Out:
# id
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24    False
#                         ...
# air_a17f0778617c76e2    False
# air_a17f0778617c76e2    False
# air_a17f0778617c76e2    False
# air_a17f0778617c76e2     True
# air_a17f0778617c76e2    False
# Name: reserve_visitors, Length: 252108, dtype: bool

# %%
df['reserve_visitors'].between(df['reserve_visitors'].quantile(.25), df['reserve_visitors'].quantile(.75))
# Out:
# id
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24    False
#                         ...
# air_a17f0778617c76e2     True
# air_a17f0778617c76e2    False
# air_a17f0778617c76e2    False
# air_a17f0778617c76e2    False
# air_a17f0778617c76e2    False
# Name: reserve_visitors, Length: 252108, dtype: bool

# %%
df['reserve_visitors'] > df['reserve_visitors'].quantile(.75)
# Out:
# id
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24    False
# air_ba937bf13d40fb24    False
#                         ...
# air_a17f0778617c76e2    False
# air_a17f0778617c76e2     True
# air_a17f0778617c76e2     True
# air_a17f0778617c76e2    False
# air_a17f0778617c76e2     True
# Name: reserve_visitors, Length: 252108, dtype: bool

# %%
df['reserve_visitors'].quantile(0.75)
# Out:
# 24.0

# %%
conditions = [
    df['reserve_visitors'] < df['reserve_visitors'].quantile(.25),
    df['reserve_visitors'].between(df['reserve_visitors'].quantile(.25), df['reserve_visitors'].quantile(.75)),
    df['reserve_visitors'] > df['reserve_visitors'].quantile(.75)
]

results = [
    'low',
    'medium',
    'high'
]

df['reservation_activity'] = np.select(conditions, results, 'Other')

# %%
df['duration'] = df['visit_date'] - df['visit_date'].min()

# %%
df['duration'] = df['duration'].dt.days

# %%
df['visit_date'] = pd.to_datetime(df['visit_date'])

# %%
df['visitors'] - 5
# Out:
# id
# air_ba937bf13d40fb24    20
# air_ba937bf13d40fb24    27
# air_ba937bf13d40fb24    24
# air_ba937bf13d40fb24    17
# air_ba937bf13d40fb24     1
#                         ..
# air_a17f0778617c76e2    44
# air_a17f0778617c76e2    55
# air_a17f0778617c76e2    64
# air_a17f0778617c76e2    26
# air_a17f0778617c76e2    21
# Name: visitors, Length: 252108, dtype: int64

# %%
df1 = pd.DataFrame({'name': ['John', 'Jill', 'Jack', 'Jane'],
                    'id':   [1, 2, 3, 4 ]})

df2 = pd.DataFrame({'age': [49, 43, 27, 51],
                    'id':   [5, 2, 3, 4 ]})

# %%
df1
# Out:
#    name  id
# 0  John   1
# 1  Jill   2
# 2  Jack   3
# 3  Jane   4

# %%
df2
# Out:
#    age  id
# 0   49   5
# 1   43   2
# 2   27   3
# 3   51   4

# %%
pd.concat([df1, df2])
# Out:
#    name  id   age
# 0  John   1   NaN
# 1  Jill   2   NaN
# 2  Jack   3   NaN
# 3  Jane   4   NaN
# 0   NaN   5  49.0
# 1   NaN   2  43.0
# 2   NaN   3  27.0
# 3   NaN   4  51.0

# %%
df1.merge(df2)
# Out:
#    name  id  age
# 0  Jill   2   43
# 1  Jack   3   27
# 2  Jane   4   51

# %%
df2.merge(df1)
# Out:
#    age  id  name
# 0   43   2  Jill
# 1   27   3  Jack
# 2   51   4  Jane

# %%
df1
# Out:
#    name  id
# 0  John   1
# 1  Jill   2
# 2  Jack   3
# 3  Jane   4

# %%
df2
# Out:
#    age  id
# 0   49   5
# 1   43   2
# 2   27   3
# 3   51   4

# %%
df1.merge(df2, how='left')
# Out:
#    name  id   age
# 0  John   1   NaN
# 1  Jill   2  43.0
# 2  Jack   3  27.0
# 3  Jane   4  51.0
# 4   NaN   5  49.0

# %%
df1
# Out:
#    name  id
# 0  John   1
# 1  Jill   2
# 2  Jack   3
# 3  Jane   4

# %%
df2
# Out:
#    age  id
# 0   49   5
# 1   43   2
# 2   27   3
# 3   51   4

# %%
air_reserve = pd.read_csv('../data/restaurant_data/air_reserve.csv')
air_store_info = pd.read_csv('../data/restaurant_data/air_store_info.csv')
air_visit_data = pd.read_csv('../data/restaurant_data/air_visit_data.csv')
date_info = pd.read_csv('../data/restaurant_data/date_info.csv')

# %%
air_reserve['visit_datetime'] = pd.to_datetime(air_reserve['visit_datetime']).dt.date

# %%
air_reserve = air_reserve.groupby(['air_store_id', 'visit_datetime'])['reserve_visitors'].sum().reset_index()

# %%
air_reserve
# Out:
#                air_store_id visit_datetime  reserve_visitors
# 0      air_00a91d42b08b08d9     2016-10-31                 2
# 1      air_00a91d42b08b08d9     2016-12-05                 9
# 2      air_00a91d42b08b08d9     2016-12-14                18
# 3      air_00a91d42b08b08d9     2016-12-17                 2
# 4      air_00a91d42b08b08d9     2016-12-20                 4
# ...                     ...            ...               ...
# 29825  air_fea5dc9594450608     2017-04-22                 2
# 29826  air_fea5dc9594450608     2017-04-25                 2
# 29827  air_fea5dc9594450608     2017-04-28                 3
# 29828  air_fea5dc9594450608     2017-05-20                 6
# 29829  air_fee8dcf4d619598e     2017-01-09                 5
#
# [29830 rows x 3 columns]

# %%
air_visit_data
# Out:
#                 air_store_id  visit_date  visitors
# 0       air_ba937bf13d40fb24  2016-01-13        25
# 1       air_ba937bf13d40fb24  2016-01-14        32
# 2       air_ba937bf13d40fb24  2016-01-15        29
# 3       air_ba937bf13d40fb24  2016-01-16        22
# 4       air_ba937bf13d40fb24  2016-01-18         6
# ...                      ...         ...       ...
# 252103  air_24e8414b9b07decb  2017-04-18         6
# 252104  air_24e8414b9b07decb  2017-04-19         6
# 252105  air_24e8414b9b07decb  2017-04-20         7
# 252106  air_24e8414b9b07decb  2017-04-21         8
# 252107  air_24e8414b9b07decb  2017-04-22         5
#
# [252108 rows x 3 columns]

# %%
air_reserve['visit_datetime'] = pd.to_datetime(air_reserve['visit_datetime'])
air_visit_data['visit_date'] = pd.to_datetime(air_visit_data['visit_date'])

# %%
master.merge(air_reserve, left_on=['air_store_id', 'visit_date'], right_on=['air_store_id', 'visit_datetime'], how='left')
# Out:
#                 air_store_id visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday
# ...                      ...        ...       ...           ...         ...
# 252103  air_24e8414b9b07decb 2017-04-18         6    2017-04-18     Tuesday
# 252104  air_24e8414b9b07decb 2017-04-19         6    2017-04-19   Wednesday
# 252105  air_24e8414b9b07decb 2017-04-20         7    2017-04-20    Thursday
# 252106  air_24e8414b9b07decb 2017-04-21         8    2017-04-21      Friday
# 252107  air_24e8414b9b07decb 2017-04-22         5    2017-04-22    Saturday
#
# ...

# %%
date_info
date_info['calendar_date'] = pd.to_datetime(date_info['calendar_date'])

# %%
master = air_visit_data.merge(date_info, left_on='visit_date', right_on='calendar_date', how='left')

# %%
master = air_visit_data.merge(date_info, left_on='visit_date', right_on='calendar_date')

# %%
master
# Out:
#                 air_store_id visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday
# ...                      ...        ...       ...           ...         ...
# 252103  air_24e8414b9b07decb 2017-04-18         6    2017-04-18     Tuesday
# 252104  air_24e8414b9b07decb 2017-04-19         6    2017-04-19   Wednesday
# 252105  air_24e8414b9b07decb 2017-04-20         7    2017-04-20    Thursday
# 252106  air_24e8414b9b07decb 2017-04-21         8    2017-04-21      Friday
# 252107  air_24e8414b9b07decb 2017-04-22         5    2017-04-22    Saturday
#
#         holiday_flg
# 0                 0
# ...

# %%
master = master.merge(air_store_info, on='air_store_id', how='left')

# %%
master = master.merge(air_store_info, on='air_store_id')

# %%
air_reserve['visit_datetime'] = pd.to_datetime(air_reserve['visit_datetime'])
air_reserve['visit_datetime'] = air_reserve['visit_datetime'].dt.date

# %%
air_reserve['visit_datetime'] = pd.to_datetime(air_reserve['visit_datetime'])

# %%
master['visit_date'] = pd.to_datetime(master['visit_date'])

# %%
master.shape
# Out:
# (252108, 10)

# %%
master.merge(air_reserve, left_on=['air_store_id', 'visit_date'], right_on=['air_store_id', 'visit_datetime'], how='left')
# Out:
#                 air_store_id visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday
# ...                      ...        ...       ...           ...         ...
# 311220  air_a17f0778617c76e2 2017-04-21        49    2017-04-21      Friday
# 311221  air_a17f0778617c76e2 2017-04-22        60    2017-04-22    Saturday
# 311222  air_a17f0778617c76e2 2017-03-26        69    2017-03-26      Sunday
# 311223  air_a17f0778617c76e2 2017-03-20        31    2017-03-20      Monday
# 311224  air_a17f0778617c76e2 2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
master
# Out:
#                 air_store_id visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday
# ...                      ...        ...       ...           ...         ...
# 311220  air_a17f0778617c76e2 2017-04-21        49    2017-04-21      Friday
# 311221  air_a17f0778617c76e2 2017-04-22        60    2017-04-22    Saturday
# 311222  air_a17f0778617c76e2 2017-03-26        69    2017-03-26      Sunday
# 311223  air_a17f0778617c76e2 2017-03-20        31    2017-03-20      Monday
# 311224  air_a17f0778617c76e2 2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
master['air_store_id'].nunique()
# Out:
# 829

# %%
air_visit_data
# Out:
#                 air_store_id  visit_date  visitors
# 0       air_ba937bf13d40fb24  2016-01-13        25
# 1       air_ba937bf13d40fb24  2016-01-14        32
# 2       air_ba937bf13d40fb24  2016-01-15        29
# 3       air_ba937bf13d40fb24  2016-01-16        22
# 4       air_ba937bf13d40fb24  2016-01-18         6
# ...                      ...         ...       ...
# 252103  air_24e8414b9b07decb  2017-04-18         6
# 252104  air_24e8414b9b07decb  2017-04-19         6
# 252105  air_24e8414b9b07decb  2017-04-20         7
# 252106  air_24e8414b9b07decb  2017-04-21         8
# 252107  air_24e8414b9b07decb  2017-04-22         5
#
# [252108 rows x 3 columns]
