# %%
import numpy as np

# %%
var = np.arange(20).reshape(5, 4)

# %%
var

# %%
var

# %%
var.mean()

# %%
var.mean(axis=0)

# %%
var.mean(axis=1)

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Jonat\dat-07-26\ClassMaterial\Unit2\data\restaurant_data\master.csv")

# %% [markdown]
# `Option` + `Command` + `C`

# %%
df.median()
# Out:
# visitors             17.000000
# holiday               0.000000
# latitude             35.658068
# longitude           139.670038
# reserve_visitors     10.000000
# dtype: float64

# %%
df.max()
# Out:
# id                        air_fff68b929994bfbd
# visit_date                          2017-04-22
# visitors                                   877
# calendar_date                       2017-04-22
# day_of_week                          Wednesday
# holiday                                      1
# genre                     Yakiniku/Korean food
# area                Ōsaka-fu Ōsaka-shi Ōhiraki
# latitude                               44.0206
# longitude                              144.273
# reserve_visitors                            96
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252108 entries, 0 to 252107
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                252108 non-null  object
#  1   visit_date        252108 non-null  object
#  2   visitors          252108 non-null  int64
#  3   calendar_date     252108 non-null  object
#  4   day_of_week       252108 non-null  object
#  5   holiday           252108 non-null  int64
#  6   genre             252108 non-null  object
#  7   area              252108 non-null  object
#  8   latitude          252108 non-null  float64
#  9   longitude         252108 non-null  float64
#  10  reserve_visitors  108394 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.2+ MB

# %%
df.median()
# Out:
# visitors             17.000000
# holiday               0.000000
# latitude             35.658068
# longitude           139.670038
# reserve_visitors     10.000000
# dtype: float64

# %%
df[['visitors', 'holiday']].mean()
# Out:
# visitors    20.973761
# holiday      0.050673
# dtype: float64

# %%
df.iloc[6]
# Out:
# id                          air_ba937bf13d40fb24
# visit_date                            2016-01-20
# visitors                                      31
# calendar_date                         2016-01-20
# day_of_week                            Wednesday
# holiday                                        0
# genre                                 Dining bar
# area                Tōkyō-to Minato-ku Shibakōen
# latitude                                 35.6581
# longitude                                139.752
# reserve_visitors                             NaN
# Name: 6, dtype: object

# %%
df.iloc[:50, 2:7]
# Out:
#     visitors calendar_date day_of_week  holiday       genre
# 0         25    2016-01-13   Wednesday        0  Dining bar
# 1         32    2016-01-14    Thursday        0  Dining bar
# 2         29    2016-01-15      Friday        0  Dining bar
# 3         22    2016-01-16    Saturday        0  Dining bar
# 4          6    2016-01-18      Monday        0  Dining bar
# 5          9    2016-01-19     Tuesday        0  Dining bar
# 6         31    2016-01-20   Wednesday        0  Dining bar
# 7         21    2016-01-21    Thursday        0  Dining bar
# 8         18    2016-01-22      Friday        0  Dining bar
# 9         26    2016-01-23    Saturday        0  Dining bar
# 10        21    2016-01-25      Monday        0  Dining bar
# 11        11    2016-01-26     Tuesday        0  Dining bar
# 12        24    2016-01-27   Wednesday        0  Dining bar
# 13        21    2016-01-28    Thursday        0  Dining bar
# 14        26    2016-01-29      Friday        0  Dining bar
# ...

# %%
df['visitors'][:50].mean()
# Out:
# 20.78

# %%
df[20:50]
# Out:
#                       id  visit_date  visitors calendar_date day_of_week  \
# 20  air_ba937bf13d40fb24  2016-02-08        19    2016-02-08      Monday
# 21  air_ba937bf13d40fb24  2016-02-09        15    2016-02-09     Tuesday
# 22  air_ba937bf13d40fb24  2016-02-10        32    2016-02-10   Wednesday
# 23  air_ba937bf13d40fb24  2016-02-11         3    2016-02-11    Thursday
# 24  air_ba937bf13d40fb24  2016-02-12        26    2016-02-12      Friday
# 25  air_ba937bf13d40fb24  2016-02-13         8    2016-02-13    Saturday
# 26  air_ba937bf13d40fb24  2016-02-15        14    2016-02-15      Monday
# 27  air_ba937bf13d40fb24  2016-02-16        15    2016-02-16     Tuesday
# 28  air_ba937bf13d40fb24  2016-02-17        17    2016-02-17   Wednesday
# 29  air_ba937bf13d40fb24  2016-02-18        22    2016-02-18    Thursday
# 30  air_ba937bf13d40fb24  2016-02-19        43    2016-02-19      Friday
# 31  air_ba937bf13d40fb24  2016-02-20        20    2016-02-20    Saturday
# ...

# %%
df.median()

# %%
df.sum()

# %%
df.mean()

# %%
df['visitors'].mean()
# Out:
# 20.973761245180636

# %%
df[['visitors', 'holiday']].median()
# Out:
# visitors    17.0
# holiday      0.0
# dtype: float64

# %%
df['visitors'][:5000].min()
# Out:
# 1

# %%
df.mode()
# Out:
#                      id  visit_date  visitors calendar_date day_of_week  \
# 0  air_5c817ef28f236bdf  2017-03-17         8    2017-03-17      Friday
#
#    holiday    genre                            area   latitude   longitude  \
# 0        0  Izakaya  Fukuoka-ken Fukuoka-shi Daimyō  33.589216  130.392813
#
#    reserve_visitors
# 0               2.0

# %%
the_list = [2, 4, 6, 8, 10, 12, 14]

# %%
the_list[4:]
# Out:
# [10, 12, 14]

# %%
the_list[-1]
# Out:
# 14

# %%
the_list[-2]
# Out:
# 12

# %%
the_list[-4:]
# Out:
# [8, 10, 12, 14]

# %%
df.iloc[:, 7:].mode()
# Out:
#                              area   latitude   longitude  reserve_visitors
# 0  Fukuoka-ken Fukuoka-shi Daimyō  33.589216  130.392813               2.0

# %%
df
# Out:
#                           id  visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24  2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24  2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24  2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24  2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24  2016-01-18         6    2016-01-18      Monday
# ...                      ...         ...       ...           ...         ...
# 252103  air_a17f0778617c76e2  2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2  2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2  2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2  2017-03-20        31    2017-03-20      Monday
# 252107  air_a17f0778617c76e2  2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
df.iloc[:250, :3].mean()
# Out:
# visitors    24.912
# dtype: float64

# %%
df[df['visitors'] > 30]
# Out:
#                           id  visit_date  visitors calendar_date day_of_week  \
# 1       air_ba937bf13d40fb24  2016-01-14        32    2016-01-14    Thursday
# 6       air_ba937bf13d40fb24  2016-01-20        31    2016-01-20   Wednesday
# 18      air_ba937bf13d40fb24  2016-02-05        45    2016-02-05      Friday
# 22      air_ba937bf13d40fb24  2016-02-10        32    2016-02-10   Wednesday
# 30      air_ba937bf13d40fb24  2016-02-19        43    2016-02-19      Friday
# ...                      ...         ...       ...           ...         ...
# 252097  air_a17f0778617c76e2  2017-04-15        61    2017-04-15    Saturday
# 252103  air_a17f0778617c76e2  2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2  2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2  2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2  2017-03-20        31    2017-03-20      Monday
#
# ...

# %%
df[df['day_of_week'] == 'Saturday']
# Out:
#                           id  visit_date  visitors calendar_date day_of_week  \
# 3       air_ba937bf13d40fb24  2016-01-16        22    2016-01-16    Saturday
# 9       air_ba937bf13d40fb24  2016-01-23        26    2016-01-23    Saturday
# 15      air_ba937bf13d40fb24  2016-01-30         6    2016-01-30    Saturday
# 19      air_ba937bf13d40fb24  2016-02-06        15    2016-02-06    Saturday
# 25      air_ba937bf13d40fb24  2016-02-13         8    2016-02-13    Saturday
# ...                      ...         ...       ...           ...         ...
# 252078  air_a17f0778617c76e2  2017-03-25        61    2017-03-25    Saturday
# 252084  air_a17f0778617c76e2  2017-04-01        38    2017-04-01    Saturday
# 252091  air_a17f0778617c76e2  2017-04-08        33    2017-04-08    Saturday
# 252097  air_a17f0778617c76e2  2017-04-15        61    2017-04-15    Saturday
# 252104  air_a17f0778617c76e2  2017-04-22        60    2017-04-22    Saturday
#
# ...

# %%
df[df['visitors'].between(10, 20)]['visitors'].mode()
# Out:
# 0    10
# dtype: int64

# %%
df[df['visitors'].between(10, 20)]
# Out:
#                           id  visit_date  visitors calendar_date day_of_week  \
# 8       air_ba937bf13d40fb24  2016-01-22        18    2016-01-22      Friday
# 11      air_ba937bf13d40fb24  2016-01-26        11    2016-01-26     Tuesday
# 16      air_ba937bf13d40fb24  2016-02-03        18    2016-02-03   Wednesday
# 17      air_ba937bf13d40fb24  2016-02-04        12    2016-02-04    Thursday
# 19      air_ba937bf13d40fb24  2016-02-06        15    2016-02-06    Saturday
# ...                      ...         ...       ...           ...         ...
# 252070  air_a17f0778617c76e2  2017-03-16        17    2017-03-16    Thursday
# 252087  air_a17f0778617c76e2  2017-04-04        10    2017-04-04     Tuesday
# 252094  air_a17f0778617c76e2  2017-04-12        10    2017-04-12   Wednesday
# 252099  air_a17f0778617c76e2  2017-04-17        19    2017-04-17      Monday
# 252100  air_a17f0778617c76e2  2017-04-18        11    2017-04-18     Tuesday
#
# ...

# %%
df[['visitors']]
# Out:
#         visitors
# 0             25
# 1             32
# 2             29
# 3             22
# 4              6
# ...          ...
# 252103        49
# 252104        60
# 252105        69
# 252106        31
# 252107        26
#
# [252108 rows x 1 columns]

# %%
df.head()
# Out:
#                      id  visit_date  visitors calendar_date day_of_week  \
# 0  air_ba937bf13d40fb24  2016-01-13        25    2016-01-13   Wednesday
# 1  air_ba937bf13d40fb24  2016-01-14        32    2016-01-14    Thursday
# 2  air_ba937bf13d40fb24  2016-01-15        29    2016-01-15      Friday
# 3  air_ba937bf13d40fb24  2016-01-16        22    2016-01-16    Saturday
# 4  air_ba937bf13d40fb24  2016-01-18         6    2016-01-18      Monday
#
#    holiday       genre                          area   latitude   longitude  \
# 0        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 1        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 2        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 3        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 4        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
#
#    reserve_visitors
# 0               NaN
# 1               NaN
# ...

# %%
df[(df['genre'] == 'Dining bar') | (df['day_of_week'] == 'Friday')]
# Out:
#                           id  visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24  2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24  2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24  2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24  2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24  2016-01-18         6    2016-01-18      Monday
# ...                      ...         ...       ...           ...         ...
# 252077  air_a17f0778617c76e2  2017-03-24       109    2017-03-24      Friday
# 252083  air_a17f0778617c76e2  2017-03-31        51    2017-03-31      Friday
# 252090  air_a17f0778617c76e2  2017-04-07        46    2017-04-07      Friday
# 252096  air_a17f0778617c76e2  2017-04-14        88    2017-04-14      Friday
# 252103  air_a17f0778617c76e2  2017-04-21        49    2017-04-21      Friday
#
# ...
