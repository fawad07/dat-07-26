# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/restaurant_data/master.csv')

# %%
df.head()

# %%
var = 'string'

# %%
df[df['day_of_week'] == 'Wednesday']

# %%
df[(df['day_of_week'] == 'Wednesday') | (df['visitors'] > 25)]['visitors']

# %%
df[df['visitors'].between(10, 20)]

# %%
df[df['day_of_week'] == 'Monday']['visitors'].mean()

# %%
print("Hi")

# %%
print

# %%
df[(df['day_of_week'] == 'Saturday') | (df['day_of_week'] == 'Sunday')]['visitors'].mean()

# %%
df[df['holiday'] == 0]['visitors'].mean()

# %%
df[df['holiday'] == 1]['visitors'].mean()

# %%
df.head()

# %%
df[df['genre'] == 'Dining bar'].max()

# %%
df[df['genre'] == 'Dining bar']['visitors'].idxmax()

# %%
df.iloc[245791]

# %%
df.iloc[:, 4:9]

# %%
df[df['holiday'] == 1]['visitors'].idxmax()

# %%
df.iloc[122871]

# %%
df.sum()

# %%
df.isnull().sum()
# Out:
# id                       0
# visit_date               0
# visitors                 0
# calendar_date            0
# day_of_week              0
# holiday                  0
# genre                    0
# area                     0
# latitude                 0
# longitude                0
# reserve_visitors    143714
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                       0
# visit_date               0
# visitors                 0
# calendar_date            0
# day_of_week              0
# holiday                  0
# genre                    0
# area                     0
# latitude                 0
# longitude                0
# reserve_visitors    143714
# dtype: int64

# %%
df['day_of_week'].value_counts()
# Out:
# Friday       40351
# Saturday     39262
# Thursday     37996
# Wednesday    36811
# Tuesday      36015
# Monday       31682
# Sunday       29991
# Name: day_of_week, dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['day_of_week'])
# Out:
# pandas.core.series.Series

# %%
df.value_counts()
# Out:
# id                    visit_date  visitors  calendar_date  day_of_week  holiday  genre             area                             latitude   longitude   reserve_visitors
# air_fff68b929994bfbd  2017-04-22  5         2017-04-22     Saturday     0        Bar/Cocktail      Tōkyō-to Nakano-ku Nakano        35.708146  139.666288  37.0                1
# air_5c817ef28f236bdf  2016-12-20  11        2016-12-20     Tuesday      0        Izakaya           Tōkyō-to Shibuya-ku Shibuya      35.661777  139.704051  9.0                 1
#                       2016-11-20  32        2016-11-20     Sunday       0        Izakaya           Tōkyō-to Shibuya-ku Shibuya      35.661777  139.704051  83.0                1
#                       2016-11-21  20        2016-11-21     Monday       0        Izakaya           Tōkyō-to Shibuya-ku Shibuya      35.661777  139.704051  2.0                 1
# ...

# %%
df['day_of_week'].value_counts()
# Out:
# Friday       40351
# Saturday     39262
# Thursday     37996
# Wednesday    36811
# Tuesday      36015
# Monday       31682
# Sunday       29991
# Name: day_of_week, dtype: int64

# %%
df.nunique()
# Out:
# id                  829
# visit_date          478
# visitors            204
# calendar_date       478
# day_of_week           7
# holiday               2
# genre                14
# area                103
# latitude            108
# longitude           108
# reserve_visitors     49
# dtype: int64

# %%
df['genre'].unique()
# Out:
# array(['Dining bar', 'Izakaya', 'Cafe/Sweets', 'Italian/French', 'Other',
#        'Yakiniku/Korean food', 'Japanese food',
#        'Okonomiyaki/Monja/Teppanyaki', 'Bar/Cocktail', 'Creative cuisine',
#        'Western food', 'Asian', 'International cuisine', 'Karaoke/Party'],
#       dtype=object)

# %%
df.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-84bc62f43960> in <module>
# ----> 1 df.unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df.median()
# Out:
# visitors             17.000000
# holiday               0.000000
# latitude             35.658068
# longitude           139.670038
# reserve_visitors     10.000000
# dtype: float64

# %%
df['visitors'].median()
# Out:
# 17.0

# %%
df['visitors'].unique()
# Out:
# array([ 25,  32,  29,  22,   6,   9,  31,  21,  18,  26,  11,  24,  12,
#         45,  15,  19,   3,   8,  14,  17,  43,  20,   7,  16,  23,  37,
#         13,  10,  27,  39,  30,  41,   1,  44,  36,  49,  51,  35,  33,
#         40,  28,  34,  46,  48,  54,  50,  53,  61,  47,  38,  57,   2,
#          4,   5,  42,  62,  55,  60,  64,  56,  86,  63,  68,  52,  58,
#         59,  71,  65,  67,  75,  77,  73,  79,  70,  66,  82,  78,  72,
#         69,  84,  81, 109,  83,  91,  74,  87,  85, 244,  80, 102,  90,
#         98, 103,  76,  94,  88,  93,  92, 239,  96, 101, 107, 119, 115,
#         95,  99,  97,  89, 116, 123, 104, 110, 127, 117, 141, 100, 118,
#        120, 113, 136, 114, 128, 112, 106, 168, 180, 137, 122, 132, 105,
#        108, 124, 121, 162, 111, 877, 228, 135, 269, 211, 351, 514, 158,
#        369, 144, 222, 182, 167, 139, 138, 181, 311, 218, 133, 175, 130,
#        129, 145, 205, 248, 328, 148, 150, 217, 207, 146, 170, 216, 142,
# ...

# %%
df.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-84bc62f43960> in <module>
# ----> 1 df.unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df.nunique()
# Out:
# id                  829
# visit_date          478
# visitors            204
# calendar_date       478
# day_of_week           7
# holiday               2
# genre                14
# area                103
# latitude            108
# longitude           108
# reserve_visitors     49
# dtype: int64

# %%
df.sort_values(by=['day_of_week', 'visitors'], ascending=[False, True])
# Out:
#                           id  visit_date  visitors calendar_date day_of_week  \
# 433     air_25e9888d30b386df  2016-03-16         1    2016-03-16   Wednesday
# 514     air_25e9888d30b386df  2016-07-27         1    2016-07-27   Wednesday
# 539     air_25e9888d30b386df  2016-09-14         1    2016-09-14   Wednesday
# 562     air_25e9888d30b386df  2016-10-26         1    2016-10-26   Wednesday
# 597     air_25e9888d30b386df  2016-12-21         1    2016-12-21   Wednesday
# ...                      ...         ...       ...           ...         ...
# 18763   air_fe58c074ec1445ea  2016-04-29       168    2016-04-29      Friday
# 122871  air_df554c4527a1cfe6  2016-12-30       205    2016-12-30      Friday
# 109721  air_681b0c56328dd2af  2016-01-22       218    2016-01-22      Friday
# 4564    air_082908692355165e  2016-04-01       244    2016-04-01      Friday
# 206336  air_eca5e0064dc9314a  2016-08-26       325    2016-08-26      Friday
#
# ...

# %%
# ?df.sort_values

# %%
dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
df.iloc[20:60, 2:7]
# Out:
#     visitors calendar_date day_of_week  holiday       genre
# 20        19    2016-02-08      Monday        0  Dining bar
# 21        15    2016-02-09     Tuesday        0  Dining bar
# 22        32    2016-02-10   Wednesday        0  Dining bar
# 23         3    2016-02-11    Thursday        1  Dining bar
# 24        26    2016-02-12      Friday        0  Dining bar
# 25         8    2016-02-13    Saturday        0  Dining bar
# 26        14    2016-02-15      Monday        0  Dining bar
# 27        15    2016-02-16     Tuesday        0  Dining bar
# 28        17    2016-02-17   Wednesday        0  Dining bar
# 29        22    2016-02-18    Thursday        0  Dining bar
# 30        43    2016-02-19      Friday        0  Dining bar
# 31        20    2016-02-20    Saturday        0  Dining bar
# 32         7    2016-02-22      Monday        0  Dining bar
# 33        16    2016-02-23     Tuesday        0  Dining bar
# 34        21    2016-02-24   Wednesday        0  Dining bar
# ...

# %%
df.loc[:, df.isnull().sum() > 0]
# Out:
#         reserve_visitors
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 252103               6.0
# 252104              37.0
# 252105              35.0
# 252106               3.0
# 252107              32.0
#
# [252108 rows x 1 columns]

# %%
df.isnull().sum() > 0
# Out:
# id                  False
# visit_date          False
# visitors            False
# calendar_date       False
# day_of_week         False
# holiday             False
# genre               False
# area                False
# latitude            False
# longitude           False
# reserve_visitors     True
# dtype: bool

# %%
df.loc[df['visitors'] > 25, :]
# Out:
#                           id  visit_date  visitors calendar_date day_of_week  \
# 1       air_ba937bf13d40fb24  2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24  2016-01-15        29    2016-01-15      Friday
# 6       air_ba937bf13d40fb24  2016-01-20        31    2016-01-20   Wednesday
# 9       air_ba937bf13d40fb24  2016-01-23        26    2016-01-23    Saturday
# 14      air_ba937bf13d40fb24  2016-01-29        26    2016-01-29      Friday
# ...                      ...         ...       ...           ...         ...
# 252103  air_a17f0778617c76e2  2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2  2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2  2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2  2017-03-20        31    2017-03-20      Monday
# 252107  air_a17f0778617c76e2  2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
df[df['visitors'] > 25]
# Out:
#                           id  visit_date  visitors calendar_date day_of_week  \
# 1       air_ba937bf13d40fb24  2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24  2016-01-15        29    2016-01-15      Friday
# 6       air_ba937bf13d40fb24  2016-01-20        31    2016-01-20   Wednesday
# 9       air_ba937bf13d40fb24  2016-01-23        26    2016-01-23    Saturday
# 14      air_ba937bf13d40fb24  2016-01-29        26    2016-01-29      Friday
# ...                      ...         ...       ...           ...         ...
# 252103  air_a17f0778617c76e2  2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2  2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2  2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2  2017-03-20        31    2017-03-20      Monday
# 252107  air_a17f0778617c76e2  2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
df[df.isnull().sum(axis=1) == 0]
# Out:
#                           id  visit_date  visitors calendar_date day_of_week  \
# 11      air_ba937bf13d40fb24  2016-01-26        11    2016-01-26     Tuesday
# 21      air_ba937bf13d40fb24  2016-02-09        15    2016-02-09     Tuesday
# 24      air_ba937bf13d40fb24  2016-02-12        26    2016-02-12      Friday
# 25      air_ba937bf13d40fb24  2016-02-13         8    2016-02-13    Saturday
# 37      air_ba937bf13d40fb24  2016-02-27        23    2016-02-27    Saturday
# ...                      ...         ...       ...           ...         ...
# 252103  air_a17f0778617c76e2  2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2  2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2  2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2  2017-03-20        31    2017-03-20      Monday
# 252107  air_a17f0778617c76e2  2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
df.notnull()
# Out:
#           id  visit_date  visitors  calendar_date  day_of_week  holiday  \
# 0       True        True      True           True         True     True
# 1       True        True      True           True         True     True
# 2       True        True      True           True         True     True
# 3       True        True      True           True         True     True
# 4       True        True      True           True         True     True
# ...      ...         ...       ...            ...          ...      ...
# 252103  True        True      True           True         True     True
# 252104  True        True      True           True         True     True
# 252105  True        True      True           True         True     True
# 252106  True        True      True           True         True     True
# 252107  True        True      True           True         True     True
#
#         genre  area  latitude  longitude  reserve_visitors
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, visit_date, visitors, calendar_date, day_of_week, holiday, genre, area, latitude, longitude, reserve_visitors]
# Index: []

# %%
df.duplicated(subset=['id', 'day_of_week', 'visitors'])

# %%
# ?df.duplicated

# %%
df[df.duplicated(subset=['id', 'day_of_week', 'visitors'])]
# Out:
#                           id  visit_date  visitors calendar_date day_of_week  \
# 13      air_ba937bf13d40fb24  2016-01-28        21    2016-01-28    Thursday
# 24      air_ba937bf13d40fb24  2016-02-12        26    2016-02-12      Friday
# 27      air_ba937bf13d40fb24  2016-02-16        15    2016-02-16     Tuesday
# 35      air_ba937bf13d40fb24  2016-02-25        21    2016-02-25    Thursday
# 40      air_ba937bf13d40fb24  2016-03-02        21    2016-03-02   Wednesday
# ...                      ...         ...       ...           ...         ...
# 251985  air_cf5ab75a0afb8af9  2017-04-22        64    2017-04-22    Saturday
# 252018  air_1c0b150f9e696a5f  2017-04-02       152    2017-04-02      Sunday
# 252035  air_1c0b150f9e696a5f  2017-04-21        89    2017-04-21      Friday
# 252097  air_a17f0778617c76e2  2017-04-15        61    2017-04-15    Saturday
# 252107  air_a17f0778617c76e2  2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
df = df.drop_duplicates(subset=['id', 'visitors', 'day_of_week'])

# %%
df
# Out:
#                           id  visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24  2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24  2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24  2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24  2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24  2016-01-18         6    2016-01-18      Monday
# ...                      ...         ...       ...           ...         ...
# 252102  air_a17f0778617c76e2  2017-04-20        22    2017-04-20    Thursday
# 252103  air_a17f0778617c76e2  2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2  2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2  2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2  2017-03-20        31    2017-03-20      Monday
#
# ...

# %%
cat_cols = df.select_dtypes(include=np.object).columns.tolist()

# %%
cat_cols
# Out:
# ['id', 'visit_date', 'calendar_date', 'day_of_week', 'genre', 'area']

# %%
df[cat_cols]
# Out:
#                           id  visit_date calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24  2016-01-13    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24  2016-01-14    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24  2016-01-15    2016-01-15      Friday
# 3       air_ba937bf13d40fb24  2016-01-16    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24  2016-01-18    2016-01-18      Monday
# ...                      ...         ...           ...         ...
# 252102  air_a17f0778617c76e2  2017-04-20    2017-04-20    Thursday
# 252103  air_a17f0778617c76e2  2017-04-21    2017-04-21      Friday
# 252104  air_a17f0778617c76e2  2017-04-22    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2  2017-03-26    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2  2017-03-20    2017-03-20      Monday
#
#                  genre                          area
# 0           Dining bar  Tōkyō-to Minato-ku Shibakōen
# 1           Dining bar  Tōkyō-to Minato-ku Shibakōen
# ...

# %%
df[df['id'].str.len() > 15]
# Out:
#                           id  visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24  2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24  2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24  2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24  2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24  2016-01-18         6    2016-01-18      Monday
# ...                      ...         ...       ...           ...         ...
# 252102  air_a17f0778617c76e2  2017-04-20        22    2017-04-20    Thursday
# 252103  air_a17f0778617c76e2  2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2  2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2  2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2  2017-03-20        31    2017-03-20      Monday
#
# ...

# %%
cat_df = df[cat_cols].copy()

for col in cat_cols:
    cat_df[col] = cat_df[col].str.len() > 25

# %%
df[cat_df.sum(axis=1) == 0]
# Out:
#                           id  visit_date  visitors calendar_date day_of_week  \
# 30204   air_9aa32b3db0fab3a5  2016-01-13        16    2016-01-13   Wednesday
# 30205   air_9aa32b3db0fab3a5  2016-01-14        11    2016-01-14    Thursday
# 30206   air_9aa32b3db0fab3a5  2016-01-15        12    2016-01-15      Friday
# 30207   air_9aa32b3db0fab3a5  2016-01-16        19    2016-01-16    Saturday
# 30208   air_9aa32b3db0fab3a5  2016-01-18        11    2016-01-18      Monday
# ...                      ...         ...       ...           ...         ...
# 252056  air_900d755ebd2f7bbd  2017-04-19       125    2017-04-19   Wednesday
# 252057  air_900d755ebd2f7bbd  2017-04-20        92    2017-04-20    Thursday
# 252058  air_900d755ebd2f7bbd  2017-04-21       114    2017-04-21      Friday
# 252059  air_900d755ebd2f7bbd  2017-04-22        83    2017-04-22    Saturday
# 252060  air_900d755ebd2f7bbd  2017-04-09        50    2017-04-09      Sunday
#
# ...

# %%
num_cols = df.select_dtypes(include=np.number).columns.tolist()

# %%
df[num_cols].mean()
# Out:
# visitors             24.837159
# holiday               0.050852
# latitude             35.660430
# longitude           137.331550
# reserve_visitors     16.649732
# dtype: float64

# %%
df[num_cols] = df[num_cols].fillna(df[num_cols].mean()).copy()

# %%
df[df['visit_date'].between('2016-01-01', '2016-06-30')]
# Out:
#                           id  visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24  2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24  2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24  2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24  2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24  2016-01-18         6    2016-01-18      Monday
# ...                      ...         ...       ...           ...         ...
# 126440  air_764f71040a413d4d  2016-06-05        59    2016-06-05      Sunday
# 126441  air_764f71040a413d4d  2016-06-12        71    2016-06-12      Sunday
# 126442  air_764f71040a413d4d  2016-06-19        75    2016-06-19      Sunday
# 126443  air_764f71040a413d4d  2016-06-26        56    2016-06-26      Sunday
# 126480  air_d98380a4aeb0290b  2016-05-25        12    2016-05-25   Wednesday
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121824 entries, 0 to 252106
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                121824 non-null  object
#  1   visit_date        121824 non-null  object
#  2   visitors          121824 non-null  int64
#  3   calendar_date     121824 non-null  object
#  4   day_of_week       121824 non-null  object
#  5   holiday           121824 non-null  int64
#  6   genre             121824 non-null  object
#  7   area              121824 non-null  object
#  8   latitude          121824 non-null  float64
#  9   longitude         121824 non-null  float64
#  10  reserve_visitors  121824 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 11.2+ MB

# %%
df['visit_date'] = pd.to_datetime(df['visit_date'])
# Out:
# <ipython-input-95-0b67689b97ec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['visit_date'] = pd.to_datetime(df['visit_date'])

# %%
df['visit_date'].dt.quarter
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 252102    2
# 252103    2
# 252104    2
# 252105    1
# 252106    1
# Name: visit_date, Length: 121824, dtype: int64

# %%
df['visit_date'].dt.is_month_end
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 252102    False
# 252103    False
# 252104    False
# 252105    False
# 252106    False
# Name: visit_date, Length: 121824, dtype: bool

# %%
df['month'] = df['visit_date'].dt.month
df['quarter'] = df['visit_date'].dt.quarter
# Out:
# <ipython-input-99-9bb77a3376fb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['visit_date'].dt.month
# <ipython-input-99-9bb77a3376fb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quarter'] = df['visit_date'].dt.quarter

# %%
df.groupby(['day_of_week', 'holiday'])[['visitors', 'reserve_visitors']].agg([np.sum, np.mean, np.std]).to_csv('../data/grouping.csv')
