# %%
with open('repos.csv') as f:
    repos = f.readlines()

# %%
# the file contents
repos
# Out:
# ['Name,URL\n',
#  'Jonathan,https://github.com/JonathanBechtel\n',
#  'Muhammad,https://github.com/fawad07\n',
#  'Carlie,https://github.com/carliedeboer\n',
#  'David,https://github.com/davidbroxmeyer']

# %%
repos = [repo.split('/')[-1] for repo in repos[1:]]

# %%
repos
# Out:
# ['JonathanBechtel\n', 'fawad07\n', 'carliedeboer\n', 'davidbroxmeyer']

# %%
usernames = [repo.replace('\n', '') for repo in repos]

# %%
[repo.replace('\n', '') for repo in repos]
# Out:
# ['JonathanBechtel', 'fawad07', 'carliedeboer', 'davidbroxmeyer']

# %%
usernames
# Out:
# ['JonathanBechtel', 'fawad07', 'carliedeboer', 'davidbroxmeyer']

# %%
repos
# Out:
# ['JonathanBechtel\n', 'fawad07\n', 'carliedeboer\n', 'davidbroxmeyer']

# %%
usernames
# Out:
# ['JonathanBechtel', 'fawad07', 'carliedeboer', 'davidbroxmeyer']

# %%
fawad_api = requests.get('https://api.github.com/users/fawad07/repos').json()

# %%
fawad_api[1]
# Out:
# {'id': 287593460,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkyODc1OTM0NjA=',
#  'name': 'FaceDetect',
#  'full_name': 'fawad07/FaceDetect',
#  'private': False,
#  'owner': {'login': 'fawad07',
#   'id': 31203033,
#   'node_id': 'MDQ6VXNlcjMxMjAzMDMz',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/31203033?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/fawad07',
#   'html_url': 'https://github.com/fawad07',
#   'followers_url': 'https://api.github.com/users/fawad07/followers',
#   'following_url': 'https://api.github.com/users/fawad07/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/fawad07/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/fawad07/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/fawad07/subscriptions',
#   'organizations_url': 'https://api.github.com/users/fawad07/orgs',
#   'repos_url': 'https://api.github.com/users/fawad07/repos',
# ...

# %%
import requests
repo_data = [requests.get(f'https://api.github.com/users/{user}/repos').json() for user in usernames]

# %%
[{}, {}, {}, {}, {}, {}, {}]

# %%
repo_data[0]
# Out:
# [{'id': 260764681,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjA3NjQ2ODE=',
#   'name': 'bitcoin',
#   'full_name': 'JonathanBechtel/bitcoin',
#   'private': False,
#   'owner': {'login': 'JonathanBechtel',
#    'id': 481696,
#    'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/481696?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JonathanBechtel',
#    'html_url': 'https://github.com/JonathanBechtel',
#    'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#    'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
# ...

# %%
repo_data = []
for user in usernames:
    url = f'https://api.github.com/users/{user}/repos'
    data = requests.get(url).json()
    repo_data.append(data)

# %%
import pandas as pd

pd.DataFrame(repo_data)
# Out:
#                                                   0   \
# 0  {'id': 260764681, 'node_id': 'MDEwOlJlcG9zaXRv...
# 1  {'id': 101350377, 'node_id': 'MDEwOlJlcG9zaXRv...
# 2  {'id': 288029505, 'node_id': 'MDEwOlJlcG9zaXRv...
# 3                                               None
#
#                                                   1   \
# 0  {'id': 72648844, 'node_id': 'MDEwOlJlcG9zaXRvc...
# 1  {'id': 287593460, 'node_id': 'MDEwOlJlcG9zaXRv...
# 2                                               None
# 3                                               None
#
#                                                   2   \
# 0  {'id': 260483209, 'node_id': 'MDEwOlJlcG9zaXRv...
# 1  {'id': 348403122, 'node_id': 'MDEwOlJlcG9zaXRv...
# 2                                               None
# 3                                               None
#
#                                                   3   \
# 0  {'id': 330519158, 'node_id': 'MDEwOlJlcG9zaXRv...
# ...

# %%
pd.DataFrame([{'a': 1, 'b': 2} for i in range(3)])
# Out:
#    a  b
# 0  1  2
# 1  1  2
# 2  1  2

# %%
repo_data
# Out:
# [[{'id': 260764681,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyNjA3NjQ2ODE=',
#    'name': 'bitcoin',
#    'full_name': 'JonathanBechtel/bitcoin',
#    'private': False,
#    'owner': {'login': 'JonathanBechtel',
#     'id': 481696,
#     'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/481696?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/JonathanBechtel',
#     'html_url': 'https://github.com/JonathanBechtel',
#     'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#     'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
# ...

# %%
repo_dicts = []

for data in repo_data:
    for repo in data:
        repo_dicts.append(repo)

# %%
repo_data = pd.DataFrame(repo_dicts)

# %%
repo_data
# Out:
#            id                           node_id                 name  \
# 0   260764681  MDEwOlJlcG9zaXRvcnkyNjA3NjQ2ODE=              bitcoin
# 1    72648844  MDEwOlJlcG9zaXRvcnk3MjY0ODg0NA==        cdc-dashboard
# 2   260483209  MDEwOlJlcG9zaXRvcnkyNjA0ODMyMDk=             covid-19
# 3   330519158  MDEwOlJlcG9zaXRvcnkzMzA1MTkxNTg=            covid-app
# 4   330856817  MDEwOlJlcG9zaXRvcnkzMzA4NTY4MTc=          dashingdemo
# 5   235342950  MDEwOlJlcG9zaXRvcnkyMzUzNDI5NTA=            DAT-01-21
# 6   340753149  MDEwOlJlcG9zaXRvcnkzNDA3NTMxNDk=            dat-02-22
# 7   364763648  MDEwOlJlcG9zaXRvcnkzNjQ3NjM2NDg=        dat-02-22-app
# 8   193928930  MDEwOlJlcG9zaXRvcnkxOTM5Mjg5MzA=            DAT-06-24
# 9   389093664  MDEwOlJlcG9zaXRvcnkzODkwOTM2NjQ=            dat-07-26
# 10  283083154  MDEwOlJlcG9zaXRvcnkyODMwODMxNTQ=            DAT-07-28
# 11  215089544  MDEwOlJlcG9zaXRvcnkyMTUwODk1NDQ=            DAT-10-14
# 12  305419317  MDEwOlJlcG9zaXRvcnkzMDU0MTkzMTc=            DAT-10-19
# ...

# %%
repo_data.to_excel('repo_data.xls', index=False)

# %%
[[{}, {}, {}], [{}, {}]]
[{}, {}, {}, {}, {}]

# %%
repo_dicts[0]
# Out:
# {'id': 260764681,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkyNjA3NjQ2ODE=',
#  'name': 'bitcoin',
#  'full_name': 'JonathanBechtel/bitcoin',
#  'private': False,
#  'owner': {'login': 'JonathanBechtel',
#   'id': 481696,
#   'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/481696?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/JonathanBechtel',
#   'html_url': 'https://github.com/JonathanBechtel',
#   'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#   'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#   'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
# ...

# %%
df_dict = {'name': [repo['name'] for repo in repo_dicts],
'html_url': [repo['html_url'] for repo in repo_dicts],
'created_at': [repo['created_at'] for repo in repo_dicts],
'owner': [repo['owner']['login'] for repo in repo_dicts]}

# %%
pd.DataFrame(df_dict)
# Out:
#                    name                                           html_url  \
# 0               bitcoin         https://github.com/JonathanBechtel/bitcoin
# 1         cdc-dashboard   https://github.com/JonathanBechtel/cdc-dashboard
# 2              covid-19        https://github.com/JonathanBechtel/covid-19
# 3             covid-app       https://github.com/JonathanBechtel/covid-app
# 4           dashingdemo     https://github.com/JonathanBechtel/dashingdemo
# 5             DAT-01-21       https://github.com/JonathanBechtel/DAT-01-21
# 6             dat-02-22       https://github.com/JonathanBechtel/dat-02-22
# 7         dat-02-22-app   https://github.com/JonathanBechtel/dat-02-22-app
# 8             DAT-06-24       https://github.com/JonathanBechtel/DAT-06-24
# 9             dat-07-26       https://github.com/JonathanBechtel/dat-07-26
# 10            DAT-07-28       https://github.com/JonathanBechtel/DAT-07-28
# ...

# %%
pd.DataFrame({'a': [2, 4, 6], 
 'b': [4, 6, 8],
 'c': [6, 8, 10]})
# Out:
#    a  b   c
# 0  2  4   6
# 1  4  6   8
# 2  6  8  10

# %%
repo_data
# Out:
#            id                           node_id                 name  \
# 0   260764681  MDEwOlJlcG9zaXRvcnkyNjA3NjQ2ODE=              bitcoin
# 1    72648844  MDEwOlJlcG9zaXRvcnk3MjY0ODg0NA==        cdc-dashboard
# 2   260483209  MDEwOlJlcG9zaXRvcnkyNjA0ODMyMDk=             covid-19
# 3   330519158  MDEwOlJlcG9zaXRvcnkzMzA1MTkxNTg=            covid-app
# 4   330856817  MDEwOlJlcG9zaXRvcnkzMzA4NTY4MTc=          dashingdemo
# 5   235342950  MDEwOlJlcG9zaXRvcnkyMzUzNDI5NTA=            DAT-01-21
# 6   340753149  MDEwOlJlcG9zaXRvcnkzNDA3NTMxNDk=            dat-02-22
# 7   364763648  MDEwOlJlcG9zaXRvcnkzNjQ3NjM2NDg=        dat-02-22-app
# 8   193928930  MDEwOlJlcG9zaXRvcnkxOTM5Mjg5MzA=            DAT-06-24
# 9   389093664  MDEwOlJlcG9zaXRvcnkzODkwOTM2NjQ=            dat-07-26
# 10  283083154  MDEwOlJlcG9zaXRvcnkyODMwODMxNTQ=            DAT-07-28
# 11  215089544  MDEwOlJlcG9zaXRvcnkyMTUwODk1NDQ=            DAT-10-14
# 12  305419317  MDEwOlJlcG9zaXRvcnkzMDU0MTkzMTc=            DAT-10-19
# ...

# %%
url = 'https://www.yelp.com/search?find_desc=Restaurants&find_loc=London'

req = requests.get(url)

# %%
req.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-89-ea8849b3977c> in <module>
# ----> 1 req.json()
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# ...

# %%
from bs4 import BeautifulSoup

scraper = BeautifulSoup(req.text)

# %%
type(scraper)
# Out:
# bs4.BeautifulSoup

# %%
paragraphs = scraper.find_all('a')

# %%
paragraphs
# Out:
# [<a class="logo-link__09f24__Em6ZC css-5r1d0t" href="/" name="" rel="" role="link" target="">Yelp</a>,
#  <a class="find-near-button__09f24__2q9wS css-1g3e5b2" data-activated="false" data-testid="responsive-suggest-submit" href="#" type="secondary"><span class="css-ardur">Cancel</span></a>,
#  <a class="header-link__09f24__1cV_I" href="/advertise/consumer_header_redirect"><div class="padding-t1__09f24__2K88R padding-r1__09f24__3TomQ padding-b1__09f24__Zwtfa padding-l1__09f24__1xY8k border-color--default__09f24__3Epto"><div class="notification-wrapper__09f24__NWj3b display--inline-block__09f24__3SvIn border-color--default__09f24__3Epto"><p class="css-8yg8ez">For Businesses</p></div></div></a>,
# ...

# %%
[paragraph.text for paragraph in paragraphs]
# Out:
# ['For Businesses',
#  'Write a Review',
#  'Filters',
#  'Suggested',
#  'Category',
#  'See all',
#  'Features',
#  'See all',
#  'Neighborhoods',
#  'See all',
#  'Distance',
#  'Delivery',
#  'Takeout',
#  'Fish & Chips££Mayfair',
#  'Fish & Chips',
#  "“A chippy befitting of it's neighborhood.\n\nClassy interior, friendly service, and a piece of fish that you'd be pleased with if served in a fine dining…”\xa0more",
#  'FrenchBritish££££Chelsea',
#  'French',
#  'British',
#  "“This wasn't the best meal that I've had, but it certainly ranks near the top.  The restaurant felt like it was a little out of the way in a quiet neighborhood,…”\xa0more",
#  'American (Traditional)Soul FoodCajun/Creole££Blackfriars',
#  'American (Traditional)',
#  'Soul Food',
#  'Cajun/Creole',
#  "“WOW, this place is delicious!\n\nOur family stopped in London for the last part of our cruise.  After touring St. Paul's Cathedral, we were pretty hungry.  We…”\xa0more",
#  'Indian££Covent Garden',
# ...

# %%
links = scraper.find_all('a', {'class': 'css-166la90'})

# %%
link_text = [link.text for link in links]

# %%
link_text
# Out:
# ['The Mayfair Chippy',
#  'Restaurant Gordon Ramsay',
#  'The Fat Bear',
#  'Dishoom',
#  'Flat Iron',
#  'Padella',
#  'Ffiona’s Restaurant',
#  'The Queens Arms',
#  'Abeno',
#  'The Golden Chippy',
#  '2',
#  '3',
#  '4',
#  '5',
#  '6',
#  '7',
#  '8',
#  '9',
#  '']

# %%
'The Fat 7 Bear'.isdigit()
# Out:
# False

# %%
titles = [text for text in link_text if not text.isdigit() and len(text) > 1]

# %%
span_class = 'reviewCount__09f24__3GsGY css-e81eai'

# %%
spans = scraper.find_all('span', {'class': span_class})

# %%
review_counts = [span.text for span in spans]

# %%
review_counts
# Out:
# ['282', '206', '123', '1850', '381', '208', '266', '120', '102', '110']

# %%
span_class = 'reviewCount__09f24__3GsGY css-e81eai'

# %%
spans = scraper.find_all('span', {'class': span_class})

# %%
num_reviews = [int(span.text) for span in spans]

# %%
num_reviews
# Out:
# [282, 206, 123, 1850, 381, 208, 266, 120, 102, 110]

# %%
div_class = 'container__09f24__sxa9-'

# %%
divs = scraper.find_all('div', {'class': div_class})

# %%
paragraphs_within_divs = [div.find_all('p') for div in divs]

# %%
paragraphs_within_divs[0]
# Out:
# [<p class="css-1j7sdmt"><span class="css-epvm6 display--inline__09f24__nqZ_W border-color--default__09f24__3Epto"><a class="css-1634hvh" href="/search?cflt=fishnchips&amp;find_loc=London" name="" rel="" role="link" target=""><button class="badge__09f24__xWRsZ color--gray-extra-light__09f24__1ZCSL size--large__09f24__2JW1p badge--interactive__09f24__bhLsk"><p class="text__09f24__2NHRu css-1hx6l2b">Fish &amp; Chips</p></button></a></span><span class="display--inline__09f24__nqZ_W border-color--default__09f24__3Epto"><span class="priceRange__09f24__2GspP css-xtpg8e">££</span></span><span class="css-e81eai">Mayfair</span></p>,
#  <p class="text__09f24__2NHRu css-1hx6l2b">Fish &amp; Chips</p>,
#  <p class="css-e81eai">“A chippy befitting of it's neighborhood.
#
# ...

# %%
<div>
    <p>The paragraph</p>
    <p>The second paragraph</p>
    <span>The span here</span>
    <img src="path/to/the/img"></img>
</div>

# %%
num_reviews
# Out:
# [282, 206, 123, 1850, 381, 208, 266, 120, 102, 110]

# %%
titles
# Out:
# ['The Mayfair Chippy',
#  'Restaurant Gordon Ramsay',
#  'The Fat Bear',
#  'Dishoom',
#  'Flat Iron',
#  'Padella',
#  'Ffiona’s Restaurant',
#  'The Queens Arms',
#  'Abeno',
#  'The Golden Chippy']

# %%
yelp_dict = {
    'title': titles,
    'reviews': num_reviews
}

# %%
pd.DataFrame(yelp_dict)
# Out:
#                       title  reviews
# 0        The Mayfair Chippy      282
# 1  Restaurant Gordon Ramsay      206
# 2              The Fat Bear      123
# 3                   Dishoom     1850
# 4                 Flat Iron      381
# 5                   Padella      208
# 6       Ffiona’s Restaurant      266
# 7           The Queens Arms      120
# 8                     Abeno      102
# 9         The Golden Chippy      110
