# %%
x = 29
y = 43

# %%
if x > 20:
    if y > 35:
        print("Here")
    else:
        print("Here instead")
else:
    if y > 35:
        print("Here")
    else:
        print("Here instead")

# %%
if x > 20 and y > 35:
    print("This statement")
elif x > 20 and y > 35:
    print("This statement is here now")
elif x < 20 and y > 35:
    print("Something in here")
else:
    print("The else statement")

# %%
stmt = "This is the string"

# %%
stmt.split('s')
# Out:
# ['Thi', ' i', ' the ', 'tring']

# %%
url = 'https://github.com/JonathanBechtel'
url2 = 'https://github.com/MuktaDhamija'

# %%
url2.split('/')[-1]
# Out:
# 'MuktaDhamija'

# %%
urls = ['https://github.com/JonathanBechtel', 'https://github.com/MuktaDhamija']

# %%
users = [url.split('/')[-1] for url in urls]

# %%
users
# Out:
# ['JonathanBechtel', 'MuktaDhamija']

# %%
url.split('/')[-1]
# Out:
# 'JonathanBechtel'

# %%
users = [
    ('John', 34, None), ('Abby', 21, 'NY'), ('Jill', 41, 'OH'), ('Jason', 59, 'AL'), ('William', 35, None),
    ('Wynona', 62, 'WY'), ('Barbara', 42, None), ('Harold', 52, None), ('Jose', 41, 'NH'), ('Ariel', 48, 'OR')
]

# %%
users[0][2]

# %%
for item in users:
    #print(item)
    for i in item:
        print(i)
# Out:
# John
# 34
# None
# Abby
# 21
# NY
# Jill
# 41
# OH
# Jason
# 59
# AL
# William
# 35
# None
# Wynona
# 62
# WY
# Barbara
# 42
# None
# Harold
# 52
# None
# Jose
# 41
# NH
# Ariel
# 48
# OR

# %%
users.append('Hi')

# %%
users
# Out:
# [('John', 34, None),
#  ('Abby', 21, 'NY'),
#  ('Jill', 41, 'OH'),
#  ('Jason', 59, 'AL'),
#  ('William', 35, None),
#  ('Wynona', 62, 'WY'),
#  ('Barbara', 42, None),
#  ('Harold', 52, None),
#  ('Jose', 41, 'NH'),
#  ('Ariel', 48, 'OR'),
#  'Hi']

# %%
info = ('Jonathan', 'Bechtel', 23)

# %%
info[0]
# Out:
# 'Jonathan'

# %%
info.append('Hi')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-3fbe986d2b4e> in <module>
# ----> 1 info.append('Hi')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
12, 13, 14
# Out:
# (12, 13, 14)

# %%
urls = ['https://github.com/JonathanBechtel',
               'https://github.com/MuktaDhamija', 
              'https://github.com/CarlieDeBoer']

# %%
usernames = []

for github_url in urls:
   user = github_url.split('/')[-1]
   usernames.append(user)

# %%
usernames
# Out:
# ['JonathanBechtel', 'MuktaDhamija', 'CarlieDeBoer']

# %%
usernames = [github_url.split('/')[-1] for github_url in urls]

# %%
usernames
# Out:
# ['JonathanBechtel', 'MuktaDhamija', 'CarlieDeBoer']

# %%
users
# Out:
# [('John', 34, None),
#  ('Abby', 21, 'NY'),
#  ('Jill', 41, 'OH'),
#  ('Jason', 59, 'AL'),
#  ('William', 35, None),
#  ('Wynona', 62, 'WY'),
#  ('Barbara', 42, None),
#  ('Harold', 52, None),
#  ('Jose', 41, 'NH'),
#  ('Ariel', 48, 'OR'),
#  'Hi']

# %%
not_nones = []

for user in users:
    for item in user:
        if item != None:
            not_nones.append(item)

# %%
not_nones
# Out:
# ['John',
#  34,
#  'Abby',
#  21,
#  'NY',
#  'Jill',
#  41,
#  'OH',
#  'Jason',
#  59,
#  'AL',
#  'William',
#  35,
#  'Wynona',
#  62,
#  'WY',
#  'Barbara',
#  42,
#  'Harold',
#  52,
#  'Jose',
#  41,
#  'NH',
#  'Ariel',
#  48,
#  'OR',
#  'H',
#  'i']

# %%
[item for user in users for item in user if item != None]
# Out:
# ['John',
#  34,
#  'Abby',
#  21,
#  'NY',
#  'Jill',
#  41,
#  'OH',
#  'Jason',
#  59,
#  'AL',
#  'William',
#  35,
#  'Wynona',
#  62,
#  'WY',
#  'Barbara',
#  42,
#  'Harold',
#  52,
#  'Jose',
#  41,
#  'NH',
#  'Ariel',
#  48,
#  'OR',
#  'H',
#  'i']

# %%
myself = {
    'name': 'Jonathan',
    'age': 36,
    'sign': 'Aquarius',
    'hobbies': ['python', 'data science', 'statistical models', 'GRADIENT BOOSTING']
}

# %%
myself['name']
# Out:
# 'Jonathan'

# %%
myself['age']
# Out:
# 36

# %%
myself['hobbies']
# Out:
# ['python', 'data science', 'statistical models', 'GRADIENT BOOSTING']

# %%
for hobby in myself['hobbies']:
    print(hobby)
# Out:
# python
# data science
# statistical models
# GRADIENT BOOSTING

# %%
import pandas as pd

# %%
df_dict = {
    'a': [1, 2, 3],
    'b': [2, 4, 6],
    'c': [4, 6, 8]
}

# %%
pd.DataFrame(df_dict)
# Out:
#    a  b  c
# 0  1  2  4
# 1  2  4  6
# 2  3  6  8

# %%
pd.DataFrame([{'name': 'John', 'age': 46} for i in range(5)])
# Out:
#    name  age
# 0  John   46
# 1  John   46
# 2  John   46
# 3  John   46
# 4  John   46

# %%
url = 'https://api.census.gov/data.json'

# %%
import requests

# %%
req = requests.get(url)

# %%
req
# Out:
# <Response [200]>

# %%
req.text
# Out:
# '{\n  "@context": "https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld",\n  "@id": "https://api.census.gov/data/1986/cbp.json",\n  "@type": "dcat:Catalog",\n  "conformsTo": "https://project-open-data.cio.gov/v1.1/schema",\n  "describedBy": "https://project-open-data.cio.gov/v1.1/schema/catalog.json",\n  "dataset": [\n    {\n      "c_vintage": 1986,\n      "c_dataset": [\n        "cbp"\n      ],\n      "c_geographyLink": "https://api.census.gov/data/1986/cbp/geography.json",\n      "c_variablesLink": "https://api.census.gov/data/1986/cbp/variables.json",\n      "c_tagsLink": "https://api.census.gov/data/1986/cbp/tags.json",\n      "c_examplesLink": "https://api.census.gov/data/1986/cbp/examples.json",\n      "c_groupsLink": "https://api.census.gov/data/1986/cbp/groups.json",\n      "c_valuesLink": "https://api.census.gov/data/1986/cbp/values.json",\n      "c_documentationLink": "http://www.census.gov/developer/",\n      "c_isAggregate": true,\n      "c_isAvailable": true,\n  
# ...

# %%
web_data = req.json()

# %%
type(web_data)
# Out:
# dict

# %%
pd.DataFrame(web_data['dataset'])
# Out:
#      c_vintage                c_dataset  \
# 0       1986.0                    [cbp]
# 1       1994.0                    [zbp]
# 2       1987.0                    [cbp]
# 3       1995.0                    [cbp]
# 4       1988.0                    [cbp]
# ..         ...                      ...
# 648     2021.0        [cps, basic, may]
# 649     2021.0        [pdb, blockgroup]
# 650     2021.0             [pdb, tract]
# 651     2021.0        [cps, basic, jun]
# 652     2008.0  [cps, immigration, aug]
#
#                                        c_geographyLink  \
# 0    https://api.census.gov/data/1986/cbp/geography...
# 1    https://api.census.gov/data/1994/zbp/geography...
# 2    https://api.census.gov/data/1987/cbp/geography...
# 3    https://api.census.gov/data/1995/cbp/geography...
# 4    https://api.census.gov/data/1988/cbp/geography...
# ..                                                 ...
# 648  https://api.census.gov/data/2021/cps/basic/may...
# ...

# %%
url = 'https://api.github.com/users/jonathanbechtel/repos'

# %%
repos = requests.get(url).json()

# %%
repos[0]
# Out:
# {'id': 260764681,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkyNjA3NjQ2ODE=',
#  'name': 'bitcoin',
#  'full_name': 'JonathanBechtel/bitcoin',
#  'private': False,
#  'owner': {'login': 'JonathanBechtel',
#   'id': 481696,
#   'node_id': 'MDQ6VXNlcjQ4MTY5Ng==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/481696?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/JonathanBechtel',
#   'html_url': 'https://github.com/JonathanBechtel',
#   'followers_url': 'https://api.github.com/users/JonathanBechtel/followers',
#   'following_url': 'https://api.github.com/users/JonathanBechtel/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/JonathanBechtel/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/JonathanBechtel/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/JonathanBechtel/subscriptions',
#   'organizations_url': 'https://api.github.com/users/JonathanBechtel/orgs',
# ...

# %%
with open('repos.csv') as f:
    repos = f.readlines()

# %%
repos
# Out:
# ['Name,URL\n',
#  'Jonathan,https://github.com/JonathanBechtel\n',
#  'Muhammad,https://github.com/fawad07\n',
#  'Carlie,https://github.com/carliedeboer\n',
#  'David,https://github.com/davidbroxmeyer']
