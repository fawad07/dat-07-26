# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing IMDb Data
#
# _Author: Kevin Markham (DC)_
#
# ---

# %% [markdown]
# For project two, you will complete a series of exercises exploring movie rating data from IMDb.
#
# For these exercises, you will be conducting basic exploratory data analysis on IMDB's movie data, looking to answer such questions as:
#
# What is the average rating per genre?
# How many different actors are in a movie?
#
# This process will help you practice your data analysis skills while becoming comfortable with Pandas.

# %% [markdown]
# ## Basic level

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline

# %% [markdown]
# #### Read in 'imdb_1000.csv' and store it in a DataFrame named movies.

# %%
movies = pd.read_csv('./data/imdb_1000.csv')
movies.head()
# Out:
#   star_rating                     title content_rating   genre duration  \
# 0         9.3  The Shawshank Redemption              R   Crime      142
# 1         9.2             The Godfather              R   Crime      175
# 2         9.1    The Godfather: Part II              R   Crime      200
# 3           9           The Dark Knight          PG-13  Action      152
# 4         8.9              Pulp Fiction              R   Crime      154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# #### Check the number of rows and columns.

# %%
# Answer:
rows = movies.shape[0]
col = movies.shape[1]
print(f"Data Rows: {rows}\nData Columns: {col}")
# Out:
# Data Rows: 1960
# Data Columns: 6

# %% [markdown]
# #### Check the data type of each column.

# %%
# Answer:
movies.dtypes
# Out:
# star_rating       object
# title             object
# content_rating    object
# genre             object
# duration          object
# actors_list       object
# dtype: object

# %% [markdown]
# #### Calculate the average movie duration.

# %%
# Answer:
movies['duration'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-308378de5415> in <module>
#       1 # Answer:
# ----> 2 movies['duration'].mean()
#
# F:\ANACONDA\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11116         )
#   11117         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11118             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11119
#   11120         # pandas\core\generic.py:10924: error: Cannot assign to a method
#
# F:\ANACONDA\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10724
#   10725     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10726         return self._stat_function(
#   10727             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10728         )
#
# F:\ANACONDA\lib\site-packages\pandas\core\generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10709         if level is not None:
#   10710             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 10711         return self._reduce(
#   10712             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10713         )
#
# F:\ANACONDA\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4180                 )
#    4181             with np.errstate(all="ignore"):
# -> 4182                 return op(delegate, skipna=skipna, **kwds)
#    4183
#    4184     def _reindex_indexer(self, new_index, indexer, copy):
#
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      71             try:
#      72                 with np.errstate(invalid="ignore"):
# ---> 73                     return f(*args, **kwargs)
#      74             except ValueError as e:
#      75                 # we want to transform an object array
#
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     133                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     134             else:
# --> 135                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     136
#     137             return result
#
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     392             mask = isna(values)
#     393
# --> 394         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     395
#     396         if datetimelike:
#
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     631
#     632     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 633     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     634
#     635     if axis is not None and getattr(the_sum, "ndim", False):
#
# F:\ANACONDA\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# #### Sort the DataFrame by duration to find the shortest and longest movies.

# %%
# Answer:
movies.sort_values(by='duration',ascending=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-2602cff618ef> in <module>
#       1 # Answer:
# ----> 2 movies.sort_values(by='duration',ascending=True)
#
# F:\ANACONDA\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5453
#    5454             by = by[0]
# -> 5455             k = self._get_label_or_level_values(by, axis=axis)
#    5456
#    5457             # need to rewrap column in Series to apply key function
#
# F:\ANACONDA\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1682             values = self.axes[axis].get_level_values(key)._values
#    1683         else:
# -> 1684             raise KeyError(key)
#    1685
#    1686         # Check for duplicates
#
# KeyError: 'duration'

# %% [markdown]
# #### Create a histogram of duration, choosing an "appropriate" number of bins.

# %%
# Answer:
plt.hist(movies['duration'], bins = 6)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# F:\ANACONDA\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'duration'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-51e155588ebb> in <module>
#       1 # Answer:
# ----> 2 plt.hist(movies['duration'], bins = 6)
#
# F:\ANACONDA\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# F:\ANACONDA\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'duration'

# %% [markdown]
# #### Use a box plot to display that same data.

# %%
# Answer:
plt.boxplot(movies['duration'])
plt.show
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# F:\ANACONDA\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'duration'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-97f2c412852a> in <module>
#       1 # Answer:
# ----> 2 plt.boxplot(movies['duration'])
#       3 plt.show
#
# F:\ANACONDA\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# F:\ANACONDA\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'duration'

# %% [markdown]
# ## Intermediate level

# %% [markdown]
# #### Count how many movies have each of the content ratings.

# %%
# Answer:
rating_dict = {
    'R' : 0,
    'G' : 0,
    'PG-13:' : 0,
    'PASSED' : 0,
    'Approved' : 0,
    'NOT RATED' : 0,
    'GP' : 0,
    'TV-MA' : 0,
    'X' : 0,
    'PG' : 0,
    'NC-17' : 0,
    'UNRATED' : 0,
    'G' : 0,
    'TV_MA' : 0
}
for i in movies['content_rating']:
    if i in rating_dict:
        rating_dict[i] = rating_dict[i] + 1
print(rating_dict)
# Out:
# {'R': 920, 'G': 64, 'PG-13:': 0, 'PASSED': 14, 'Approved': 0, 'NOT RATED': 130, 'GP': 6, 'TV-MA': 2, 'X': 8, 'PG': 246, 'NC-17': 14, 'UNRATED': 76, 'TV_MA': 0}

# %%
movies['content_rating'].value_counts()
# Out:
# R                 920
# PG-13             378
# PG                246
# NOT RATED         130
# APPROVED           94
# UNRATED            76
# G                  64
# PASSED             14
# NC-17              14
# X                   8
# GP                  6
# TV-MA               2
# content_rating      1
# Name: content_rating, dtype: int64

# %% [markdown]
# #### Use a visualization to display that same data, including a title and x and y labels.

# %%
# Answer:
#create bar chart
width = list(rating_dict)
height = list(rating_dict.values())
plt.bar(width, height)
#x-axis label
plt.xlabel('Rating')
#y-axis label
plt.ylabel('Number of Ratings')
#show
plt.show()

# %% [markdown]
# #### Convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP.

# %%
# Answer:
movies = movies.replace(['NOT RATED', 'APPROVED', 'PASSED', 'GP'], 'UNRATED')
movies.head(50)
# Out:
#    star_rating                                              title  \
# 0          9.3                           The Shawshank Redemption
# 1          9.2                                      The Godfather
# 2          9.1                             The Godfather: Part II
# 3            9                                    The Dark Knight
# 4          8.9                                       Pulp Fiction
# 5          8.9                                       12 Angry Men
# 6          8.9                     The Good, the Bad and the Ugly
# 7          8.9      The Lord of the Rings: The Return of the King
# 8          8.9                                   Schindler's List
# 9          8.9                                         Fight Club
# 10         8.8  The Lord of the Rings: The Fellowship of the Ring
# 11         8.8                                          Inception
# 12         8.8     Star Wars: Episode V - The Empire Strikes Back
# 13         8.8                                       Forrest Gump
# 14         8.8              The Lord of the Rings: The Two Towers
# 15         8.7                                       Interstellar
# 16         8.7                    One Flew Over the Cuckoo's Nest
# 17         8.7                                      Seven Samurai
# 18         8.7                                         Goodfellas
# 19         8.7                                          Star Wars
# 20         8.7                                         The Matrix
# 21         8.7                                        City of God
# 22         8.7                              It's a Wonderful Life
# 23         8.7                                 The Usual Suspects
# 24         8.7                                              Se7en
# 25         8.6                                  Life Is Beautiful
# 26         8.6                       Once Upon a Time in the West
# 27         8.6                           The Silence of the Lambs
# 28         8.6                             Leon: The Professional
# 29         8.6                                        City Lights
# 30         8.6                                      Spirited Away
# 31         8.6                                   The Intouchables
# 32         8.6                                         Casablanca
# 33         8.6                                           Whiplash
# 34         8.6                                 American History X
# 35         8.6                                       Modern Times
# 36         8.6                                Saving Private Ryan
# 37         8.6                            Raiders of the Lost Ark
# 38         8.6                                        Rear Window
# 39         8.6                                             Psycho
# 40         8.5                                     The Green Mile
# 41         8.5                                       Sunset Blvd.
# 42         8.5                                        The Pianist
# 43         8.5                              The Dark Knight Rises
# 44         8.5                                          Gladiator
# 45         8.5                         Terminator 2: Judgment Day
# 46         8.5                                            Memento
# 47         8.5                                   Taare Zameen Par
# 48         8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 49         8.5                                       The Departed
#
#    content_rating      genre duration  \
# 0               R      Crime      142
# 1               R      Crime      175
# 2               R      Crime      200
# 3           PG-13     Action      152
# 4               R      Crime      154
# 5         UNRATED      Drama       96
# 6         UNRATED    Western      161
# 7           PG-13  Adventure      201
# 8               R  Biography      195
# 9               R      Drama      139
# 10          PG-13  Adventure      178
# 11          PG-13     Action      148
# 12             PG     Action      124
# 13          PG-13      Drama      142
# 14          PG-13  Adventure      179
# 15          PG-13  Adventure      169
# 16              R      Drama      133
# 17        UNRATED      Drama      207
# 18              R  Biography      146
# 19             PG     Action      121
# 20              R     Action      136
# 21              R      Crime      130
# 22        UNRATED      Drama      130
# 23              R      Crime      106
# 24              R      Drama      127
# 25          PG-13     Comedy      116
# 26          PG-13    Western      175
# 27              R      Drama      118
# 28              R      Crime      110
# 29        UNRATED     Comedy       87
# 30             PG  Animation      125
# 31              R  Biography      112
# 32             PG      Drama      102
# 33              R      Drama      107
# 34              R      Crime      119
# 35              G     Comedy       87
# 36              R     Action      169
# 37             PG     Action      115
# 38        UNRATED    Mystery      112
# 39              R     Horror      109
# 40              R      Crime      189
# 41        UNRATED      Drama      110
# 42              R  Biography      150
# 43          PG-13     Action      165
# 44              R     Action      155
# 45              R     Action      137
# 46              R    Mystery      113
# 47             PG      Drama      165
# 48             PG     Comedy       95
# 49              R      Crime      151
#
#                                           actors_list
# 0   [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1     [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3   [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4   [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5   [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 6   [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
# 7   [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 8   [u'Liam Neeson', u'Ralph Fiennes', u'Ben Kings...
# 9   [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...
# 10  [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# 11  [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# 12  [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# 13    [u'Tom Hanks', u'Robin Wright', u'Gary Sinise']
# 14  [u'Elijah Wood', u'Ian McKellen', u'Viggo Mort...
# 15  [u'Matthew McConaughey', u'Anne Hathaway', u'J...
# 16  [u'Jack Nicholson', u'Louise Fletcher', u'Mich...
# 17  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 18   [u'Robert De Niro', u'Ray Liotta', u'Joe Pesci']
# 19  [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# 20  [u'Keanu Reeves', u'Laurence Fishburne', u'Car...
# 21  [u'Alexandre Rodrigues', u'Matheus Nachtergael...
# 22  [u'James Stewart', u'Donna Reed', u'Lionel Bar...
# 23  [u'Kevin Spacey', u'Gabriel Byrne', u'Chazz Pa...
# 24  [u'Morgan Freeman', u'Brad Pitt', u'Kevin Spac...
# 25  [u'Roberto Benigni', u'Nicoletta Braschi', u'G...
# 26  [u'Henry Fonda', u'Charles Bronson', u'Claudia...
# 27  [u'Jodie Foster', u'Anthony Hopkins', u'Lawren...
# 28  [u'Jean Reno', u'Gary Oldman', u'Natalie Portm...
# 29  [u'Charles Chaplin', u'Virginia Cherrill', u'F...
# 30  [u'Daveigh Chase', u'Suzanne Pleshette', u'Miy...
# 31  [u'Fran\xe7ois Cluzet', u'Omar Sy', u'Anne Le ...
# 32  [u'Humphrey Bogart', u'Ingrid Bergman', u'Paul...
# 33  [u'Miles Teller', u'J.K. Simmons', u'Melissa B...
# 34  [u'Edward Norton', u'Edward Furlong', u"Beverl...
# 35  [u'Charles Chaplin', u'Paulette Goddard', u'He...
# 36     [u'Tom Hanks', u'Matt Damon', u'Tom Sizemore']
# 37  [u'Harrison Ford', u'Karen Allen', u'Paul Free...
# 38  [u'James Stewart', u'Grace Kelly', u'Wendell C...
# 39  [u'Anthony Perkins', u'Janet Leigh', u'Vera Mi...
# 40  [u'Tom Hanks', u'Michael Clarke Duncan', u'Dav...
# 41  [u'William Holden', u'Gloria Swanson', u'Erich...
# 42  [u'Adrien Brody', u'Thomas Kretschmann', u'Fra...
# 43  [u'Christian Bale', u'Tom Hardy', u'Anne Hatha...
# 44  [u'Russell Crowe', u'Joaquin Phoenix', u'Conni...
# 45  [u'Arnold Schwarzenegger', u'Linda Hamilton', ...
# 46  [u'Guy Pearce', u'Carrie-Anne Moss', u'Joe Pan...
# 47  [u'Darsheel Safary', u'Aamir Khan', u'Tanay Ch...
# 48  [u'Peter Sellers', u'George C. Scott', u'Sterl...
# 49  [u'Leonardo DiCaprio', u'Matt Damon', u'Jack N...

# %% [markdown]
# #### Convert the following content ratings to "NC-17": X, TV-MA.

# %%
# Answer:
movies = movies.replace(['X', 'TV-MA'], 'NC-17')
movies.tail(50)
# Out:
#      star_rating                                            title  \
# 1910         7.5                                  Say Anything...
# 1911         7.4                                  Man on the Moon
# 1912         7.4                                     Mean Streets
# 1913         7.4        Harry Potter and the Order of the Phoenix
# 1914         7.4                                      Beetlejuice
# 1915         7.4                             Crazy, Stupid, Love.
# 1916         7.4                                        Excalibur
# 1917         7.4                                        True Grit
# 1918         7.4                                        Labyrinth
# 1919         7.4                              Alice in Wonderland
# 1920         7.4                                   Predestination
# 1921         7.4                           Much Ado About Nothing
# 1922         7.4                                 A Bridge Too Far
# 1923         7.4                                  Raising Arizona
# 1924         7.4                                  The Bucket List
# 1925         7.4                              Terms of Endearment
# 1926         7.4                                     Take Shelter
# 1927         7.4                                  Far from Heaven
# 1928         7.4                                       Eraserhead
# 1929         7.4                                       Frances Ha
# 1930         7.4                                       Home Alone
# 1931         7.4                                            Bound
# 1932         7.4                                    Sleepy Hollow
# 1933         7.4                                     Pirate Radio
# 1934         7.4                            The NeverEnding Story
# 1935         7.4                                            X-Men
# 1936         7.4                                 Zero Dark Thirty
# 1937         7.4                         Manhattan Murder Mystery
# 1938         7.4                      National Lampoon's Vacation
# 1939         7.4                               My Sister's Keeper
# 1940         7.4                             Deconstructing Harry
# 1941         7.4                                 The Way Way Back
# 1942         7.4                                           Capote
# 1943         7.4                               Driving Miss Daisy
# 1944         7.4                                  La Femme Nikita
# 1945         7.4                                          Lincoln
# 1946         7.4                                        Limitless
# 1947         7.4                               The Simpsons Movie
# 1948         7.4                                         The Rock
# 1949         7.4                              The English Patient
# 1950         7.4                              Law Abiding Citizen
# 1951         7.4                                      Wonder Boys
# 1952         7.4                               Death at a Funeral
# 1953         7.4                                   Blue Valentine
# 1954         7.4                            The Cider House Rules
# 1955         7.4                                          Tootsie
# 1956         7.4                      Back to the Future Part III
# 1957         7.4  Master and Commander: The Far Side of the World
# 1958         7.4                                      Poltergeist
# 1959         7.4                                      Wall Street
#
#      content_rating      genre duration  \
# 1910          PG-13     Comedy      100
# 1911              R  Biography      118
# 1912              R      Crime      112
# 1913          PG-13  Adventure      138
# 1914             PG     Comedy       92
# 1915          PG-13     Comedy      118
# 1916              R  Adventure      140
# 1917            NaN  Adventure      128
# 1918             PG  Adventure      101
# 1919              G  Animation       75
# 1920              R      Drama       97
# 1921          PG-13     Comedy      111
# 1922             PG      Drama      175
# 1923          PG-13     Comedy       94
# 1924          PG-13  Adventure       97
# 1925              R     Comedy      132
# 1926              R      Drama      120
# 1927          PG-13      Drama      107
# 1928        UNRATED      Drama       89
# 1929              R     Comedy       86
# 1930             PG     Comedy      103
# 1931              R      Crime      108
# 1932              R      Drama      105
# 1933              R     Comedy      117
# 1934             PG  Adventure      102
# 1935          PG-13     Action      104
# 1936              R      Drama      157
# 1937             PG     Comedy      104
# 1938              R     Comedy       98
# 1939          PG-13      Drama      109
# 1940              R     Comedy       96
# 1941          PG-13     Comedy      103
# 1942              R  Biography      114
# 1943             PG     Comedy       99
# 1944              R     Action      118
# 1945          PG-13  Biography      150
# 1946          PG-13    Mystery      105
# 1947          PG-13  Animation       87
# 1948              R     Action      136
# 1949              R      Drama      162
# 1950              R      Crime      109
# 1951              R      Drama      107
# 1952              R     Comedy       90
# 1953          NC-17      Drama      112
# 1954          PG-13      Drama      126
# 1955             PG     Comedy      116
# 1956             PG  Adventure      118
# 1957          PG-13     Action      138
# 1958             PG     Horror      114
# 1959              R      Crime      126
#
#                                             actors_list
# 1910    [u'John Cusack', u'Ione Skye', u'John Mahoney']
# 1911  [u'Jim Carrey', u'Danny DeVito', u'Gerry Becker']
# 1912  [u'Robert De Niro', u'Harvey Keitel', u'David ...
# 1913  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 1914  [u'Alec Baldwin', u'Geena Davis', u'Michael Ke...
# 1915  [u'Steve Carell', u'Ryan Gosling', u'Julianne ...
# 1916  [u'Nigel Terry', u'Helen Mirren', u'Nicholas C...
# 1917    [u'John Wayne', u'Kim Darby', u'Glen Campbell']
# 1918  [u'David Bowie', u'Jennifer Connelly', u'Toby ...
# 1919  [u'Kathryn Beaumont', u'Ed Wynn', u'Richard Ha...
# 1920   [u'Ethan Hawke', u'Sarah Snook', u'Noah Taylor']
# 1921  [u'Kenneth Branagh', u'Emma Thompson', u'Keanu...
# 1922  [u'Sean Connery', u"Ryan O'Neal", u'Michael Ca...
# 1923  [u'Nicolas Cage', u'Holly Hunter', u'Trey Wils...
# 1924  [u'Jack Nicholson', u'Morgan Freeman', u'Sean ...
# 1925  [u'Shirley MacLaine', u'Debra Winger', u'Jack ...
# 1926  [u'Michael Shannon', u'Jessica Chastain', u'Sh...
# 1927  [u'Julianne Moore', u'Dennis Quaid', u'Dennis ...
# 1928  [u'Jack Nance', u'Charlotte Stewart', u'Allen ...
# 1929  [u'Greta Gerwig', u'Mickey Sumner', u'Adam Dri...
# 1930  [u'Macaulay Culkin', u'Joe Pesci', u'Daniel St...
# 1931  [u'Jennifer Tilly', u'Gina Gershon', u'Joe Pan...
# 1932  [u'Johnny Depp', u'Christina Ricci', u'Miranda...
# 1933  [u'Philip Seymour Hoffman', u'Bill Nighy', u'N...
# 1934  [u'Noah Hathaway', u'Barret Oliver', u'Tami St...
# 1935  [u'Patrick Stewart', u'Hugh Jackman', u'Ian Mc...
# 1936  [u'Jessica Chastain', u'Joel Edgerton', u'Chri...
# 1937  [u'Woody Allen', u'Diane Keaton', u'Jerry Adler']
# 1938  [u'Chevy Chase', u"Beverly D'Angelo", u'Imogen...
# 1939  [u'Cameron Diaz', u'Abigail Breslin', u'Alec B...
# 1940  [u'Woody Allen', u'Judy Davis', u'Julia Louis-...
# 1941  [u'Steve Carell', u'Toni Collette', u'Allison ...
# 1942  [u'Philip Seymour Hoffman', u'Clifton Collins ...
# 1943  [u'Morgan Freeman', u'Jessica Tandy', u'Dan Ay...
# 1944  [u'Anne Parillaud', u'Marc Duret', u'Patrick F...
# 1945  [u'Daniel Day-Lewis', u'Sally Field', u'David ...
# 1946  [u'Bradley Cooper', u'Anna Friel', u'Abbie Cor...
# 1947  [u'Dan Castellaneta', u'Julie Kavner', u'Nancy...
# 1948   [u'Sean Connery', u'Nicolas Cage', u'Ed Harris']
# 1949  [u'Ralph Fiennes', u'Juliette Binoche', u'Will...
# 1950  [u'Gerard Butler', u'Jamie Foxx', u'Leslie Bibb']
# 1951  [u'Michael Douglas', u'Tobey Maguire', u'Franc...
# 1952  [u'Matthew Macfadyen', u'Peter Dinklage', u'Ew...
# 1953  [u'Ryan Gosling', u'Michelle Williams', u'John...
# 1954  [u'Tobey Maguire', u'Charlize Theron', u'Micha...
# 1955  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 1956  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 1957  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 1958  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 1959  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...

# %% [markdown]
# #### Count the number of missing values in each column.

# %%
# Answer:
isNull = movies[movies['content_rating'].isnull()]
isNull
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
# 979      =======                                 NaN            NaN
# 1168         8.2  Butch Cassidy and the Sundance Kid            NaN
# 1630         7.7                   Where Eagles Dare            NaN
# 1917         7.4                           True Grit            NaN
#
#           genre duration                                        actors_list
# 187   Biography      110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649      Action      158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936   Adventure      128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']
# 979         NaN      NaN                                                NaN
# 1168  Biography      110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 1630     Action      158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 1917  Adventure      128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %% [markdown]
# #### If there are missing values: examine them, then fill them in with "reasonable" values.

# %%
# Answer:
isNull = movies.replace(['NaN'], 'UNKNOWN')
isNull.tail(50)
# Out:
#      star_rating                                            title  \
# 1910         7.5                                  Say Anything...
# 1911         7.4                                  Man on the Moon
# 1912         7.4                                     Mean Streets
# 1913         7.4        Harry Potter and the Order of the Phoenix
# 1914         7.4                                      Beetlejuice
# 1915         7.4                             Crazy, Stupid, Love.
# 1916         7.4                                        Excalibur
# 1917         7.4                                        True Grit
# 1918         7.4                                        Labyrinth
# 1919         7.4                              Alice in Wonderland
# 1920         7.4                                   Predestination
# 1921         7.4                           Much Ado About Nothing
# 1922         7.4                                 A Bridge Too Far
# 1923         7.4                                  Raising Arizona
# 1924         7.4                                  The Bucket List
# 1925         7.4                              Terms of Endearment
# 1926         7.4                                     Take Shelter
# 1927         7.4                                  Far from Heaven
# 1928         7.4                                       Eraserhead
# 1929         7.4                                       Frances Ha
# 1930         7.4                                       Home Alone
# 1931         7.4                                            Bound
# 1932         7.4                                    Sleepy Hollow
# 1933         7.4                                     Pirate Radio
# 1934         7.4                            The NeverEnding Story
# 1935         7.4                                            X-Men
# 1936         7.4                                 Zero Dark Thirty
# 1937         7.4                         Manhattan Murder Mystery
# 1938         7.4                      National Lampoon's Vacation
# 1939         7.4                               My Sister's Keeper
# 1940         7.4                             Deconstructing Harry
# 1941         7.4                                 The Way Way Back
# 1942         7.4                                           Capote
# 1943         7.4                               Driving Miss Daisy
# 1944         7.4                                  La Femme Nikita
# 1945         7.4                                          Lincoln
# 1946         7.4                                        Limitless
# 1947         7.4                               The Simpsons Movie
# 1948         7.4                                         The Rock
# 1949         7.4                              The English Patient
# 1950         7.4                              Law Abiding Citizen
# 1951         7.4                                      Wonder Boys
# 1952         7.4                               Death at a Funeral
# 1953         7.4                                   Blue Valentine
# 1954         7.4                            The Cider House Rules
# 1955         7.4                                          Tootsie
# 1956         7.4                      Back to the Future Part III
# 1957         7.4  Master and Commander: The Far Side of the World
# 1958         7.4                                      Poltergeist
# 1959         7.4                                      Wall Street
#
#      content_rating      genre duration  \
# 1910          PG-13     Comedy      100
# 1911              R  Biography      118
# 1912              R      Crime      112
# 1913          PG-13  Adventure      138
# 1914             PG     Comedy       92
# 1915          PG-13     Comedy      118
# 1916              R  Adventure      140
# 1917            NaN  Adventure      128
# 1918             PG  Adventure      101
# 1919              G  Animation       75
# 1920              R      Drama       97
# 1921          PG-13     Comedy      111
# 1922             PG      Drama      175
# 1923          PG-13     Comedy       94
# 1924          PG-13  Adventure       97
# 1925              R     Comedy      132
# 1926              R      Drama      120
# 1927          PG-13      Drama      107
# 1928        UNRATED      Drama       89
# 1929              R     Comedy       86
# 1930             PG     Comedy      103
# 1931              R      Crime      108
# 1932              R      Drama      105
# 1933              R     Comedy      117
# 1934             PG  Adventure      102
# 1935          PG-13     Action      104
# 1936              R      Drama      157
# 1937             PG     Comedy      104
# 1938              R     Comedy       98
# 1939          PG-13      Drama      109
# 1940              R     Comedy       96
# 1941          PG-13     Comedy      103
# 1942              R  Biography      114
# 1943             PG     Comedy       99
# 1944              R     Action      118
# 1945          PG-13  Biography      150
# 1946          PG-13    Mystery      105
# 1947          PG-13  Animation       87
# 1948              R     Action      136
# 1949              R      Drama      162
# 1950              R      Crime      109
# 1951              R      Drama      107
# 1952              R     Comedy       90
# 1953          NC-17      Drama      112
# 1954          PG-13      Drama      126
# 1955             PG     Comedy      116
# 1956             PG  Adventure      118
# 1957          PG-13     Action      138
# 1958             PG     Horror      114
# 1959              R      Crime      126
#
#                                             actors_list
# 1910    [u'John Cusack', u'Ione Skye', u'John Mahoney']
# 1911  [u'Jim Carrey', u'Danny DeVito', u'Gerry Becker']
# 1912  [u'Robert De Niro', u'Harvey Keitel', u'David ...
# 1913  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 1914  [u'Alec Baldwin', u'Geena Davis', u'Michael Ke...
# 1915  [u'Steve Carell', u'Ryan Gosling', u'Julianne ...
# 1916  [u'Nigel Terry', u'Helen Mirren', u'Nicholas C...
# 1917    [u'John Wayne', u'Kim Darby', u'Glen Campbell']
# 1918  [u'David Bowie', u'Jennifer Connelly', u'Toby ...
# 1919  [u'Kathryn Beaumont', u'Ed Wynn', u'Richard Ha...
# 1920   [u'Ethan Hawke', u'Sarah Snook', u'Noah Taylor']
# 1921  [u'Kenneth Branagh', u'Emma Thompson', u'Keanu...
# 1922  [u'Sean Connery', u"Ryan O'Neal", u'Michael Ca...
# 1923  [u'Nicolas Cage', u'Holly Hunter', u'Trey Wils...
# 1924  [u'Jack Nicholson', u'Morgan Freeman', u'Sean ...
# 1925  [u'Shirley MacLaine', u'Debra Winger', u'Jack ...
# 1926  [u'Michael Shannon', u'Jessica Chastain', u'Sh...
# 1927  [u'Julianne Moore', u'Dennis Quaid', u'Dennis ...
# 1928  [u'Jack Nance', u'Charlotte Stewart', u'Allen ...
# 1929  [u'Greta Gerwig', u'Mickey Sumner', u'Adam Dri...
# 1930  [u'Macaulay Culkin', u'Joe Pesci', u'Daniel St...
# 1931  [u'Jennifer Tilly', u'Gina Gershon', u'Joe Pan...
# 1932  [u'Johnny Depp', u'Christina Ricci', u'Miranda...
# 1933  [u'Philip Seymour Hoffman', u'Bill Nighy', u'N...
# 1934  [u'Noah Hathaway', u'Barret Oliver', u'Tami St...
# 1935  [u'Patrick Stewart', u'Hugh Jackman', u'Ian Mc...
# 1936  [u'Jessica Chastain', u'Joel Edgerton', u'Chri...
# 1937  [u'Woody Allen', u'Diane Keaton', u'Jerry Adler']
# 1938  [u'Chevy Chase', u"Beverly D'Angelo", u'Imogen...
# 1939  [u'Cameron Diaz', u'Abigail Breslin', u'Alec B...
# 1940  [u'Woody Allen', u'Judy Davis', u'Julia Louis-...
# 1941  [u'Steve Carell', u'Toni Collette', u'Allison ...
# 1942  [u'Philip Seymour Hoffman', u'Clifton Collins ...
# 1943  [u'Morgan Freeman', u'Jessica Tandy', u'Dan Ay...
# 1944  [u'Anne Parillaud', u'Marc Duret', u'Patrick F...
# 1945  [u'Daniel Day-Lewis', u'Sally Field', u'David ...
# 1946  [u'Bradley Cooper', u'Anna Friel', u'Abbie Cor...
# 1947  [u'Dan Castellaneta', u'Julie Kavner', u'Nancy...
# 1948   [u'Sean Connery', u'Nicolas Cage', u'Ed Harris']
# 1949  [u'Ralph Fiennes', u'Juliette Binoche', u'Will...
# 1950  [u'Gerard Butler', u'Jamie Foxx', u'Leslie Bibb']
# 1951  [u'Michael Douglas', u'Tobey Maguire', u'Franc...
# 1952  [u'Matthew Macfadyen', u'Peter Dinklage', u'Ew...
# 1953  [u'Ryan Gosling', u'Michelle Williams', u'John...
# 1954  [u'Tobey Maguire', u'Charlize Theron', u'Micha...
# 1955  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 1956  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 1957  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 1958  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 1959  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...

# %% [markdown]
# #### Calculate the average star rating for movies 2 hours or longer, and compare that with the average star rating for movies shorter than 2 hours.

# %%
# Answer
str_rating_mov_2hrs_plus = movies[movies['duration'] > 120]['star_rating'].mean()
str_rating_mov_2hrs_less = movies[movies['duration'] < 120]['star_rating'].mean()
print(f"Average star rating for movies 2 hours or longer: {str_rating_mov_2hrs_plus}\nAverage star rating for movies shorter than 2 hours: {str_rating_mov_2hrs_less}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-aa7b1d0f213b> in <module>
#       1 # Answer
# ----> 2 str_rating_mov_2hrs_plus = movies[movies['duration'] > 120]['star_rating'].mean()
#       3 str_rating_mov_2hrs_less = movies[movies['duration'] < 120]['star_rating'].mean()
#       4 print(f"Average star rating for movies 2 hours or longer: {str_rating_mov_2hrs_plus}\nAverage star rating for movies shorter than 2 hours: {str_rating_mov_2hrs_less}")
#
# F:\ANACONDA\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# F:\ANACONDA\lib\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      43     @unpack_zerodim_and_defer("__gt__")
#      44     def __gt__(self, other):
# ---> 45         return self._cmp_method(other, operator.gt)
#      46
#      47     @unpack_zerodim_and_defer("__ge__")
#
# F:\ANACONDA\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    4976         rvalues = extract_array(other, extract_numpy=True)
#    4977
# -> 4978         res_values = ops.comparison_op(lvalues, rvalues, op)
#    4979
#    4980         return self._construct_result(res_values, name=res_name)
#
# F:\ANACONDA\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     241
#     242     elif is_object_dtype(lvalues.dtype):
# --> 243         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     244
#     245     else:
#
# F:\ANACONDA\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      53         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      54     else:
# ---> 55         result = libops.scalar_compare(x.ravel(), y, op)
#      56     return result.reshape(x.shape)
#      57
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# #### Use a visualization to detect whether there is a relationship between duration and star rating.

# %%
# Answer:
relavent_data =  movies.groupby('star_rating')['duration'].mean().reset_index()
fig = px.bar(relavent_data, x='star_rating', y='duration', barmode='group')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-15-7544f3b46b14> in <module>
#       1 # Answer:
# ----> 2 relavent_data =  movies.groupby('star_rating')['duration'].mean().reset_index()
#       3 fig = px.bar(relavent_data, x='star_rating', y='duration', barmode='group')
#       4 fig.show()
#
# F:\ANACONDA\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, numeric_only)
#    1494         Name: B, dtype: float64
#    1495         """
# -> 1496         return self._cython_agg_general(
#    1497             "mean",
#    1498             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
#
# F:\ANACONDA\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1079
#    1080         if not output:
# -> 1081             raise DataError("No numeric types to aggregate")
#    1082
#    1083         return self._wrap_aggregated_output(output, index=self.grouper.result_index)
#
# DataError: No numeric types to aggregate

# %% [markdown]
# #### Calculate the average duration for each genre.

# %%
# Answer:
#movies['genre']
#create dictionary with any values and genre as the keys
genre_dict = {}
for i in movies['genre']:
    genre_dict[i] = i
#genre_dict 
#for each genre (keys) values are the mean duration 
for i in movies['genre']:
    genre_dict[i] = movies[movies.genre == i]['duration'].mean()
    
print(f'Average duration of each Genre')
genre_dict
#movies[movies['genre']]['duration'].mean()    # <-- ask what i am doing wrong here
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1536         try:
# -> 1537             x = float(x)
#    1538         except ValueError:
#
# ValueError: could not convert string to float: 'duration'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1540             try:
# -> 1541                 x = complex(x)
#    1542             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-e2471f7e30ae> in <module>
#       8 #for each genre (keys) values are the mean duration
#       9 for i in movies['genre']:
# ---> 10     genre_dict[i] = movies[movies.genre == i]['duration'].mean()
#      11
#      12 print(f'Average duration of each Genre')
#
# F:\ANACONDA\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11116         )
#   11117         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11118             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11119
#   11120         # pandas\core\generic.py:10924: error: Cannot assign to a method
#
# F:\ANACONDA\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10724
#   10725     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10726         return self._stat_function(
#   10727             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10728         )
#
# F:\ANACONDA\lib\site-packages\pandas\core\generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10709         if level is not None:
#   10710             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 10711         return self._reduce(
#   10712             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10713         )
#
# F:\ANACONDA\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4180                 )
#    4181             with np.errstate(all="ignore"):
# -> 4182                 return op(delegate, skipna=skipna, **kwds)
#    4183
#    4184     def _reindex_indexer(self, new_index, indexer, copy):
#
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      71             try:
#      72                 with np.errstate(invalid="ignore"):
# ---> 73                     return f(*args, **kwargs)
#      74             except ValueError as e:
#      75                 # we want to transform an object array
#
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     133                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     134             else:
# --> 135                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     136
#     137             return result
#
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     392             mask = isna(values)
#     393
# --> 394         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     395
#     396         if datetimelike:
#
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     631
#     632     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 633     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     634
#     635     if axis is not None and getattr(the_sum, "ndim", False):
#
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1542             except ValueError as err:
#    1543                 # e.g. "foo"
# -> 1544                 raise TypeError(f"Could not convert {x} to numeric") from err
#    1545     return x
#    1546
#
# TypeError: Could not convert duration to numeric

# %%
movies.groupby('genre')['duration'].mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-17-203200551b86> in <module>
# ----> 1 movies.groupby('genre')['duration'].mean()
#
# F:\ANACONDA\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, numeric_only)
#    1494         Name: B, dtype: float64
#    1495         """
# -> 1496         return self._cython_agg_general(
#    1497             "mean",
#    1498             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
#
# F:\ANACONDA\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1079
#    1080         if not output:
# -> 1081             raise DataError("No numeric types to aggregate")
#    1082
#    1083         return self._wrap_aggregated_output(output, index=self.grouper.result_index)
#
# DataError: No numeric types to aggregate

# %% [markdown]
# ## Advanced level

# %% [markdown]
# #### Visualize the relationship between content rating and duration.

# %%
# Answer:

relavent_data = movies.groupby('content_rating')['duration'].mean().reset_index()
fig = px.bar(relavent_data, x='content_rating', y='duration', barmode='group')
fig.show()



#------INITIAL APPROACH-------------------------------------------------------------
#def values_toString(aDict):
#    temp_list = list(aDict.values())
#    values_list = []
#    for i in temp_list:
#        temp = str(i)
#        values_list.append(temp)
#    return values_list


#def keys_toString(aDict):
#    new_list = list(aDict)
#    for i in new_list:
#        temp = str(i)
#        new_list.append(temp)
#    return new_list



#keys:content_rating, values : mean duration
#content_rating_dict = {i : movies['duration'].mean() for i in movies['content_rating']} 

#dict keys list
#content_rating_list = list(content_rating_dict)

#movie_duration_dict = {i : 'time' for i in movies['duration']}
#content_rating_x_axis = list(content_rating_dict)                 #keys_toString(content_rating_dict) 
#Content_rating_values_y_axis = list(content_rating_dict.values())        #values_toString(content_rating_dict)


#Content_rating_values_y_axis = values_toString(content_rating_dict)   #DEBUGGING STATEMENT
#Content_rating_values_y_axis        #debugging statement REMOVE LATER!!


#y_axis

#plt.bar({'Content Rating' : content_rating_x_axis, 'Average Movie Content Duration' : Content_rating_values_y_axis})
#movies.plot.bar(x=content_rating_dict, y='y_axis', rot=0)

#fig = plt.figure()
#ax = fig.add_axes([0, 0, 1, 1])
#ax.bar(content_rating_x_axis, Content_rating_values_y_axis)



#------------BAR CHART CODE-------------------------------

#plt.bar(content_rating_x_axis, Content_rating_values_y_axis)   <--- TypeError: missing Height attribute ?

#x-axis label
#plt.xlabel('COntent Rating')
#y-axis label
#plt.ylabel('Average Movie Content Duration')
#show
#plt.show()

#----------------END OF INITIAL APPROACH--------------------------------


#DEBUGGING STATEMENTS : GooGLE SEARCHES APPROACHES
#width = list(rating_dict)
#height = list(rating_dict.values())

#fig = plt.figure()
#ax = fig.add_axes([0,0,1,1])
#langs = ['C', 'C++', 'Java', 'Python', 'PHP']plt.bar(content_rating_x_axis, Content_rating_values_y_axis)
#students = [23,17,35,29,12]
#ax.bar(langs,students)
#plt.show()

# %% [markdown]
# #### Determine the top rated movie (by star rating) for each genre.

# %%
# Answer:

#for each genre (keys) values are the mean duration 
for i in movies['genre']:
    genre_dict[i] = movies[movies.genre == i]['star_rating'].max()
    
print(f'Top rated movie by star rating of each Genre\n')
genre_dict
# Out:
# Top rated movie by star rating of each Genre
# {'Crime': '9.3',
#  'Action': '9',
#  'Drama': '8.9',
#  'Western': '8.9',
#  'Adventure': '8.9',
#  'Biography': '8.9',
#  'Comedy': '8.6',
#  'Animation': '8.6',
#  'Mystery': '8.6',
#  'Horror': '8.6',
#  'Film-Noir': '8.3',
#  'Sci-Fi': '8.2',
#  'History': '8',
#  'Thriller': '8',
#  'Family': '7.9',
#  'Fantasy': '7.7',
#  nan: nan,
#  'genre': 'star_rating'}

# %%
group_values = movies.groupby('genre')['star_rating'].idxmax().values
movies.iloc[group_values]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-2178d3f7bf48> in <module>
# ----> 1 group_values = movies.groupby('genre')['star_rating'].idxmax().values
#       2 movies.iloc[group_values]
#
# F:\ANACONDA\lib\site-packages\pandas\core\groupby\groupby.py in wrapper(*args, **kwargs)
#     815                 return self.apply(curried)
#     816
# --> 817             return self._python_apply_general(curried, self._obj_with_exclusions)
#     818
#     819         wrapper.__name__ = name
#
# F:\ANACONDA\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f, data)
#     926             data after applying f
#     927         """
# --> 928         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     929
#     930         return self._wrap_applied_output(
#
# F:\ANACONDA\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     236             # group might be modified
#     237             group_axes = group.axes
# --> 238             res = f(group)
#     239             if not _is_indexed_like(res, group_axes, axis):
#     240                 mutated = True
#
# F:\ANACONDA\lib\site-packages\pandas\core\groupby\groupby.py in curried(x)
#     804
#     805             def curried(x):
# --> 806                 return f(x, *args, **kwargs)
#     807
#     808             # preserve the name so we can detect it when calling plot methods,
#
# F:\ANACONDA\lib\site-packages\pandas\core\series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    2172         """
#    2173         skipna = nv.validate_argmax_with_skipna(skipna, args, kwargs)
# -> 2174         i = nanops.nanargmax(self._values, skipna=skipna)
#    2175         if i == -1:
#    2176             return np.nan
#
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      66             if any(self.check(obj) for obj in obj_iter):
#      67                 f_name = f.__name__.replace("nan", "")
# ---> 68                 raise TypeError(
#      69                     f"reduction operation '{f_name}' not allowed for this dtype"
#      70                 )
#
# TypeError: reduction operation 'argmax' not allowed for this dtype

# %% [markdown]
# #### Check if there are multiple movies with the same title, and if so, determine if they are actually duplicates.

# %% [raw]
# - Ask why does the for loop does not work

# %%
# Answer:
'''
duplicates = movies[movies['title'].duplicated()]
duplicate_loc_dict = {}
#duplicates

#TODO - for titles is movies data
for i in movies['title']:
    #TODO - if i in the duplicate list
    #Set Dict key to title and set value to list of index
    if i in duplicates['title']:
        duplicate_loc_dict[i] = list(i).append(movies['title'].index())
duplicate_loc_dict
#duplicates


#movies[movies['title'] == 'True Grit']   ----DEBUGGING STATEMENT
'''

# %%
movies[movies['title'].duplicated(keep=False)]   #shows duplicat titles
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3              9                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ...          ...                                              ...
# 1955         7.4                                          Tootsie
# 1956         7.4                      Back to the Future Part III
# 1957         7.4  Master and Commander: The Far Side of the World
# 1958         7.4                                      Poltergeist
# 1959         7.4                                      Wall Street
#
#      content_rating      genre duration  \
# 0                 R      Crime      142
# 1                 R      Crime      175
# 2                 R      Crime      200
# 3             PG-13     Action      152
# 4                 R      Crime      154
# ...             ...        ...      ...
# 1955             PG     Comedy      116
# 1956             PG  Adventure      118
# 1957          PG-13     Action      138
# 1958             PG     Horror      114
# 1959              R      Crime      126
#
#                                             actors_list
# 0     [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1       [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2     [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3     [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4     [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ...                                                 ...
# 1955  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 1956  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 1957  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 1958  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 1959  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [1958 rows x 6 columns]

# %% [markdown]
# #### Calculate the average star rating for each genre, but only include genres with at least 10 movies

# %% [markdown]
# #### Option 1: manually create a list of relevant genres, then filter using that list

# %%
# Answer:
#CELL FILTERS OUT THE GENRE WITH 10 OR MORE MOVIES
'''
parameter: a dictionary
return: new dictionary with values greater than 10
Description: method takes a dictionary of all genres
            and return a new dictianary with the values greater than 
            10
'''
def genre_more_than_10(aDict):
    newDict = { }
    for i in aDict:
        if aDict[i] > 10:
            newDict[i] = aDict[i]
    return newDict

#dict key == genre, dict value == count of genre
#genre_dict has count of all genre greater and less than 10
#new_genre_dict has count of all genre > 10

genre_dict = dict(movies['genre'].value_counts())
new_genre_dict = genre_more_than_10(genre_dict)



#DEBUGGING STATEMENTS
#new_genre_dict
#movies['genre'].value_counts()
#movies[movies['genre'] == 'Crime']['genre'].value_counts()
#movies['genre'].value_counts() > 10

# %%
#CONTINUE OF PREVIOUS CELL: TAKES THE KEYS FROM DICTIONARY
#CONVERT IN LIST AND LOOPS THROUGH THE LIST 
#COMPARES movies['genre'] WITH GENRE IN LIST
#TAKES THE VALUE COUNT AND MEAN OF THAT GENRE

#Collect only keys from genre dict
keys = list(new_genre_dict)

for i in keys:
    print(f'{i}')
    print(movies[ movies['genre'] == i]['star_rating'].value_counts().mean())
    #print()
    

#DEBUGGING STATEMENTS
#movies[ movies['genre'] == 'Crime']['star_rating'].value_counts()
#movies[ movies['genre'] == 'Crime']['genre'].value_counts()     #<-- 124 crimes
# Out:
# Drama
# 34.75
# Comedy
# 24.0
# Action
# 17.0
# Crime
# 13.777777777777779
# Biography
# 10.266666666666667
# Adventure
# 10.0
# Animation
# 9.538461538461538
# Horror
# 5.8
# Mystery
# 2.909090909090909
# Western
# 2.5714285714285716

# %% [markdown]
# #### Option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# %%
# Answer:
movies[movies['star_rating'] < 10]['genre'].value_counts()
temp = {}
for i in movies['genre']:
    temp[i] = movies[movies.genre == i]['star_rating'].mean()
temp
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-b70c60b40a45> in <module>
#       1 # Answer:
# ----> 2 movies[movies['star_rating'] < 10]['genre'].value_counts()
#       3 temp = {}
#       4 for i in movies['genre']:
#       5     temp[i] = movies[movies.genre == i]['star_rating'].mean()
#
# F:\ANACONDA\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# F:\ANACONDA\lib\site-packages\pandas\core\arraylike.py in __lt__(self, other)
#      35     @unpack_zerodim_and_defer("__lt__")
#      36     def __lt__(self, other):
# ---> 37         return self._cmp_method(other, operator.lt)
#      38
#      39     @unpack_zerodim_and_defer("__le__")
#
# F:\ANACONDA\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    4976         rvalues = extract_array(other, extract_numpy=True)
#    4977
# -> 4978         res_values = ops.comparison_op(lvalues, rvalues, op)
#    4979
#    4980         return self._construct_result(res_values, name=res_name)
#
# F:\ANACONDA\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     241
#     242     elif is_object_dtype(lvalues.dtype):
# --> 243         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     244
#     245     else:
#
# F:\ANACONDA\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      53         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      54     else:
# ---> 55         result = libops.scalar_compare(x.ravel(), y, op)
#      56     return result.reshape(x.shape)
#      57
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# #### Option 3: calculate the average star rating for all genres, then filter using a boolean Series

# %%
# Answer:
movies.groupby(['genre', 'star_rating']).mean() > 10
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-24-3e55a8322041> in <module>
#       1 # Answer:
# ----> 2 movies.groupby(['genre', 'star_rating']).mean() > 10
#
# F:\ANACONDA\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, numeric_only)
#    1494         Name: B, dtype: float64
#    1495         """
# -> 1496         return self._cython_agg_general(
#    1497             "mean",
#    1498             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
#
# F:\ANACONDA\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1013         self, how: str, alt=None, numeric_only: bool = True, min_count: int = -1
#    1014     ) -> DataFrame:
# -> 1015         agg_mgr = self._cython_agg_blocks(
#    1016             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#    1017         )
#
# F:\ANACONDA\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1119
#    1120         if not len(new_mgr):
# -> 1121             raise DataError("No numeric types to aggregate")
#    1122
#    1123         return new_mgr
#
# DataError: No numeric types to aggregate

# %% [markdown]
# #### Option 4: aggregate by count and mean, then filter using the count

# %%
# Answer:
movies.agg({'star_rating' : 'mean' ,'genre' : 'count'})    #debugging Statement
genre_count = movies['genre'].value_counts()
genres = genre_count[genre_count >= 10].index
result_dict = {}
for i in movies['genre']:
    if i in genres:
       result_dict = dict(movies.groupby('genre')['star_rating'].agg(['mean', 'count'])) 
result_dict

#counts = movies['genre'].value_counts()
#idx = counts[counts >= 10].index
#movies[movies.genre.isin(idx)].groupby('genre')['star_rating'].agg(['mean', 'count'])
#movies[movies.genre.isin(idx)].groupby('genre')['star_rating'].agg(['mean', 'count'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1536         try:
# -> 1537             x = float(x)
#    1538         except ValueError:
#
# ValueError: could not convert string to float: '9.39.29.198.98.98.98.98.98.98.88.88.88.88.88.78.78.78.78.78.78.78.78.78.78.68.68.68.68.68.68.68.68.68.68.68.68.68.68.68.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.188888888888888888888888888888888888888888888888888888888888888888888888888888888888888888888888887.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.4=======star_rating9.39.29.198.98.98.98.98.98.98.88.88.88.88.88.78.78.78.78.78.78.78.78.78.78.68.68.68.68.68.68.68.68.68.68.68.68.68.68.68.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.188888888888888888888888888888888888888888888888888888888888888888888888888888888888888888888888887.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.9 ...
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1540             try:
# -> 1541                 x = complex(x)
#    1542             except ValueError as err:
#
# ValueError: could not convert string to complex: '9.39.29.198.98.98.98.98.98.98.88.88.88.88.88.78.78.78.78.78.78.78.78.78.78.68.68.68.68.68.68.68.68.68.68.68.68.68.68.68.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.188888888888888888888888888888888888888888888888888888888888888888888888888888888888888888888888887.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.4=======star_rating9.39.29.198.98.98.98.98.98.98.88.88.88.88.88.78.78.78.78.78.78.78.78.78.78.68.68.68.68.68.68.68.68.68.68.68.68.68.68.68.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.188888888888888888888888888888888888888888888888888888888888888888888888888888888888888888888888887.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97 ...
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# F:\ANACONDA\lib\site-packages\pandas\core\frame.py in aggregate(self, func, axis, *args, **kwargs)
#    7577         try:
# -> 7578             result, how = self._aggregate(func, axis, *args, **kwargs)
#    7579         except TypeError as err:
#
# F:\ANACONDA\lib\site-packages\pandas\core\frame.py in _aggregate(self, arg, axis, *args, **kwargs)
#    7608             return result, how
# -> 7609         return aggregate(self, arg, *args, **kwargs)
#    7610
#
# F:\ANACONDA\lib\site-packages\pandas\core\aggregation.py in aggregate(obj, arg, *args, **kwargs)
#     581         arg = cast(AggFuncTypeDict, arg)
# --> 582         return agg_dict_like(obj, arg, _axis), True
#     583     elif is_list_like(arg):
#
# F:\ANACONDA\lib\site-packages\pandas\core\aggregation.py in agg_dict_like(obj, arg, _axis)
#     767         # key used for column selection and output
# --> 768         results = {key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()}
#     769
#
# F:\ANACONDA\lib\site-packages\pandas\core\aggregation.py in <dictcomp>(.0)
#     767         # key used for column selection and output
# --> 768         results = {key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()}
#     769
#
# F:\ANACONDA\lib\site-packages\pandas\core\series.py in aggregate(self, func, axis, *args, **kwargs)
#    3973
# -> 3974         result, how = aggregate(self, func, *args, **kwargs)
#    3975         if result is None:
#
# F:\ANACONDA\lib\site-packages\pandas\core\aggregation.py in aggregate(obj, arg, *args, **kwargs)
#     578     if isinstance(arg, str):
# --> 579         return obj._try_aggregate_string_function(arg, *args, **kwargs), None
#     580     elif is_dict_like(arg):
#
# F:\ANACONDA\lib\site-packages\pandas\core\base.py in _try_aggregate_string_function(self, arg, *args, **kwargs)
#     314             if callable(f):
# --> 315                 return f(*args, **kwargs)
#     316
#
# F:\ANACONDA\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11117         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11118             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11119
#
# F:\ANACONDA\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10725     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10726         return self._stat_function(
#   10727             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#
# F:\ANACONDA\lib\site-packages\pandas\core\generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10710             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 10711         return self._reduce(
#   10712             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#
# F:\ANACONDA\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4181             with np.errstate(all="ignore"):
# -> 4182                 return op(delegate, skipna=skipna, **kwds)
#    4183
#
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      72                 with np.errstate(invalid="ignore"):
# ---> 73                     return f(*args, **kwargs)
#      74             except ValueError as e:
#
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     134             else:
# --> 135                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     136
#
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     393
# --> 394         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     395
#
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     632     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 633     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     634
#
# F:\ANACONDA\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1543                 # e.g. "foo"
# -> 1544                 raise TypeError(f"Could not convert {x} to numeric") from err
#    1545     return x
#
# TypeError: Could not convert 9.39.29.198.98.98.98.98.98.98.88.88.88.88.88.78.78.78.78.78.78.78.78.78.78.68.68.68.68.68.68.68.68.68.68.68.68.68.68.68.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.188888888888888888888888888888888888888888888888888888888888888888888888888888888888888888888888887.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.4=======star_rating9.39.29.198.98.98.98.98.98.98.88.88.88.88.88.78.78.78.78.78.78.78.78.78.78.68.68.68.68.68.68.68.68.68.68.68.68.68.68.68.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.188888888888888888888888888888888888888888888888888888888888888888888888888888888888888888888888887.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97 ...
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-ebef0129e9b2> in <module>
#       1 # Answer:
# ----> 2 movies.agg({'star_rating' : 'mean' ,'genre' : 'count'})    #debugging Statement
#       3 genre_count = movies['genre'].value_counts()
#       4 genres = genre_count[genre_count >= 10].index
#       5 result_dict = {}
#
# F:\ANACONDA\lib\site-packages\pandas\core\frame.py in aggregate(self, func, axis, *args, **kwargs)
#    7582                 f"incompatible data and dtype: {err}"
#    7583             )
# -> 7584             raise exc from err
#    7585         if result is None:
#    7586             return self.apply(func, axis=axis, args=args, **kwargs)
#
# TypeError: DataFrame constructor called with incompatible data and dtype: Could not convert 9.39.29.198.98.98.98.98.98.98.88.88.88.88.88.78.78.78.78.78.78.78.78.78.78.68.68.68.68.68.68.68.68.68.68.68.68.68.68.68.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.188888888888888888888888888888888888888888888888888888888888888888888888888888888888888888888888887.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.87.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.77.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.67.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.57.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.47.4=======star_rating9.39.29.198.98.98.98.98.98.98.88.88.88.88.88.78.78.78.78.78.78.78.78.78.78.68.68.68.68.68.68.68.68.68.68.68.68.68.68.68.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.58.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.48.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.38.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.28.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.18.188888888888888888888888888888888888888888888888888888888888888888888888888888888888888888888888887.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97.97 ...

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Figure out something "interesting" using the actors data!

# %%
 # Answer
movies.sort_values("star_rating", inplace = True) 
filtering = movies['duration'] > 120
movies.where(filtering,inplace=True)
movies.dropna()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-0076d9b31455> in <module>
#       1 # Answer
#       2 movies.sort_values("star_rating", inplace = True)
# ----> 3 filtering = movies['duration'] > 120
#       4 movies.where(filtering,inplace=True)
#       5 movies.dropna()
#
# F:\ANACONDA\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# F:\ANACONDA\lib\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      43     @unpack_zerodim_and_defer("__gt__")
#      44     def __gt__(self, other):
# ---> 45         return self._cmp_method(other, operator.gt)
#      46
#      47     @unpack_zerodim_and_defer("__ge__")
#
# F:\ANACONDA\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    4976         rvalues = extract_array(other, extract_numpy=True)
#    4977
# -> 4978         res_values = ops.comparison_op(lvalues, rvalues, op)
#    4979
#    4980         return self._construct_result(res_values, name=res_name)
#
# F:\ANACONDA\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     241
#     242     elif is_object_dtype(lvalues.dtype):
# --> 243         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     244
#     245     else:
#
# F:\ANACONDA\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      53         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      54     else:
# ---> 55         result = libops.scalar_compare(x.ravel(), y, op)
#      56     return result.reshape(x.shape)
#      57
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
movies.sort_values("title", inplace = True) 
filtering = movies['content_rating'] == 'R'
movies.where(filtering,inplace=True)
movies.dropna()
# Out:
#      star_rating             title content_rating      genre duration  \
# 1182         8.1  12 Years a Slave              R  Biography      134
# 201          8.1  12 Years a Slave              R  Biography      134
# 698          7.6         127 Hours              R  Adventure       94
# 1679         7.6         127 Hours              R  Adventure       94
# 910          7.5              2046              R      Drama      129
# ...          ...               ...            ...        ...      ...
# 677          7.7            Zodiac              R      Crime      157
# 1596         7.7        Zombieland              R     Comedy       88
# 615          7.7        Zombieland              R     Comedy       88
# 1845         7.5             [Rec]              R     Horror       78
# 864          7.5             [Rec]              R     Horror       78
#
#                                             actors_list
# 1182  [u'Chiwetel Ejiofor', u'Michael Kenneth Willia...
# 201   [u'Chiwetel Ejiofor', u'Michael Kenneth Willia...
# 698   [u'James Franco', u'Amber Tamblyn', u'Kate Mara']
# 1679  [u'James Franco', u'Amber Tamblyn', u'Kate Mara']
# 910   [u'Tony Chiu Wai Leung', u'Ziyi Zhang', u'Faye...
# ...                                                 ...
# 677   [u'Jake Gyllenhaal', u'Robert Downey Jr.', u'M...
# 1596  [u'Jesse Eisenberg', u'Emma Stone', u'Woody Ha...
# 615   [u'Jesse Eisenberg', u'Emma Stone', u'Woody Ha...
# 1845  [u'Manuela Velasco', u'Ferran Terraza', u'Jorg...
# 864   [u'Manuela Velasco', u'Ferran Terraza', u'Jorg...
#
# [920 rows x 6 columns]
